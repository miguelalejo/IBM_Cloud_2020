# %%
# @hidden_cell
# The project token is an authorization token that is used to access project resources like data sources, connections, and used by platform APIs.
from project_lib import Project
project = Project(project_id='37c38aec-dd59-459e-9476-b66647391e91', project_access_token='p-3e4938acbcfb7a4c93c09bb850f913ff5338e297')
pc = project.project_context

# %% [markdown]
# # MARATONA BEHIND THE CODE 2020
#
# ## DESAFIO 6 - ANAHUAC

# %% [markdown]
# ### Introducción

# %% [markdown]
# En este desafio, usted usará herramientas de IBM como Watson Studio (o Cloud Pak for Data) para construir un modelo baseado en Machine Learning capaz de preveer si un estudante irá continuar o abandonará su curso.

# %% [markdown]
# <hr>

# %% [markdown]
# ## Installing Libs

# %%
# !pip install scikit-learn --upgrade
# !pip install imblearn --upgrade
# Out:
# Requirement already up-to-date: scikit-learn in /opt/conda/envs/Python36/lib/python3.6/site-packages (0.23.2)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from scikit-learn) (1.15.4)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from scikit-learn) (0.16.0)
# Requirement already satisfied, skipping upgrade: scipy>=0.19.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from scikit-learn) (2.1.0)
# Collecting imblearn
#   Downloading https://files.pythonhosted.org/packages/81/a7/4179e6ebfd654bd0eac0b9c06125b8b4c96a9d0a8ff9e9507eb2a26d2d7e/imblearn-0.0-py2.py3-none-any.whl
# Collecting imbalanced-learn (from imblearn)
#   Downloading https://files.pythonhosted.org/packages/c8/81/8db4d87b03b998fda7c6f835d807c9ae4e3b141f978597b8d7f31600be15/imbalanced_learn-0.7.0-py3-none-any.whl (167kB)
#      |████████████████████████████████| 174kB 8.0MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from imbalanced-learn->imblearn) (0.16.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from imbalanced-learn->imblearn) (1.15.4)
# Requirement already satisfied, skipping upgrade: scikit-learn>=0.23 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from imbalanced-learn->imblearn) (0.23.2)
# Requirement already satisfied, skipping upgrade: scipy>=0.19.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from imbalanced-learn->imblearn) (1.2.0)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from scikit-learn>=0.23->imbalanced-learn->imblearn) (2.1.0)
# Installing collected packages: imbalanced-learn, imblearn
# Successfully installed imbalanced-learn-0.7.0 imblearn-0.0

# %%
# !pip install xgboost --upgrade
# Out:
# Requirement already up-to-date: xgboost in /opt/conda/envs/Python36/lib/python3.6/site-packages (1.2.0)
# Requirement already satisfied, skipping upgrade: scipy in /opt/conda/envs/Python36/lib/python3.6/site-packages (from xgboost) (1.2.0)
# Requirement already satisfied, skipping upgrade: numpy in /opt/conda/envs/Python36/lib/python3.6/site-packages (from xgboost) (1.15.4)

# %% [markdown]
# <hr>

# %% [markdown]
# ## Loading the .csv dataset from GitHub

# %%
import pandas as pd
from sklearn.compose import ColumnTransformer
from sklearn.base import BaseEstimator, TransformerMixin
import numpy as np
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier, VotingClassifier, AdaBoostClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, classification_report
from tensorflow.keras import layers
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold, cross_validate, cross_val_score, RandomizedSearchCV
import seaborn as sns
import matplotlib.gridspec as gridspec
from sklearn.decomposition import PCA

# %%
# !wget --no-check-certificate --content-disposition https://raw.githubusercontent.com/vanderlei-test/dataset2/master/datasets/ForTraining.csv
df_base_for_training = pd.read_csv(r'ForTraining.csv')
df_base_for_training.head()
# Out:
# --2020-09-18 07:17:17--  https://raw.githubusercontent.com/vanderlei-test/dataset2/master/datasets/ForTraining.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.48.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.48.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 92376 (90K) [text/plain]
# Saving to: ‘ForTraining.csv.1’
#
# 100%[======================================>] 92,376      --.-K/s   in 0.005s
#
# 2020-09-18 07:17:18 (17.8 MB/s) - ‘ForTraining.csv.1’ saved [92376/92376]
#    studentId            reducido      ciclo Graduado
# 0    88588.0        Interv. Edu.  2019 - 08       No
# 1    81135.0           Educacion  2019 - 05       Si
# 2    80926.0  Direc. Estrat. Neg  2019 - 05       Si
# 3    82415.0               B. I.  2019 - 06       Si
# 4    90082.0       Est. Temprana  2019 - 08       No

# %% [markdown]
# Descripción: La primera tabla mostrada arriba tiene 4 columnas, 3 son features and el target: `Graduado` that has a binary values={Si, No}.
#
# Usted puede, y debe, usar mas data que esta disponible para construir su modelo. Los siguientes archivos .csv presentados:

# %%
# !wget --no-check-certificate --content-disposition https://raw.githubusercontent.com/vanderlei-test/dataset2/master/datasets/OrdenMaterias.csv
df_orden_materias = pd.read_csv(r'OrdenMaterias.csv')
df_orden_materias.head(100)
# Out:
# --2020-09-18 07:17:19--  https://raw.githubusercontent.com/vanderlei-test/dataset2/master/datasets/OrdenMaterias.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.48.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.48.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 63920 (62K) [text/plain]
# Saving to: ‘OrdenMaterias.csv.1’
#
# 100%[======================================>] 63,920      --.-K/s   in 0.003s
#
# 2020-09-18 07:17:19 (18.6 MB/s) - ‘OrdenMaterias.csv.1’ saved [63920/63920]
#                       reducido                      2017 - 03  \
# 0      Act. Derecho Contratual                      Sin clase
# 1                    Adm. Emp.                      Sin clase
# 2                 Adm. Riesgos                      Sin clase
# 3                   Adm. Salud                      Sin clase
# 4                   Admon Fin.                      Sin clase
# 5           Alim. Y Nut. Salud                      Sin clase
# 6                Analitica Web                      Sin clase
# 7                   Autolesion                      Sin clase
# 8                        B. I.                      Sin clase
# 9        Bien. Salud y Calidad                      Sin clase
# 10                    Big Data                      Sin clase
# 11             Big Data en Edu                      Sin clase
# 12              Bio. Nutricion                      Sin clase
# 13                  Blockchain                      Sin clase
# 14              Bus. Analytics                      Sin clase
# 15           Calidad Educativa                      Sin clase
# 16               Ciberjusticia                      Sin clase
# 17              Ciberseguridad                      Sin clase
# 18             Cloud Computing                      Sin clase
# 19            Coaching de Vida                      Sin clase
# 20               Coaching Edu.                      Sin clase
# 21                  Com. Corp.                      Sin clase
# 22  Com. Estra. Respon. Social                      Sin clase
# 23            Com. Mindfulness                      Sin clase
# 24         Comp. Dig. Docentes  La Tecnología en la Educación
# 25            Comp. Directivas                      Sin clase
# 26            Comp. Doc. S XXI                      Sin clase
# 27               Crianza Hijos                      Sin clase
# 28               Dere. Digital                      Sin clase
# 29             Dere. Sanitario                      Sin clase
# ..                         ...                            ...
# 70                       I. A.                      Sin clase
# 71                   Inc. Edu.                      Sin clase
# 72           Inclusion Laboral                      Sin clase
# 73            Inn. Diseno Edu.                      Sin clase
# 74               Inn. Negocios                      Sin clase
# 75              Inn. Tec. Edu.                      Sin clase
# 76                Interv. Edu.                      Sin clase
# 77            Interv. Psicoped                      Sin clase
# 78                  Intro. Fin   Finanzas para no Financieros
# 79               Inv. Mercados                      Sin clase
# 80           Lider. Inst. Edu.                      Sin clase
# 81             Lit. Lat. S. XX                      Sin clase
# 82              Marca Personal                      Sin clase
# 83                  Med. Sueno                      Sin clase
# 84               Mercadotecnia         Liderazgo y Motivación
# 85                Mkt. Digital                      Sin clase
# 86           Mkt. Farmaceutico                      Sin clase
# 87        Mkt. Farmaceutico A.                      Sin clase
# 88              Monitores Esc.                      Sin clase
# 89         Neg. Dig. Y Eco. C.                      Sin clase
# 90              Neuromarketing                      Sin clase
# 91       Nutricion y Antiaging                      Sin clase
# 92              Obesidad. Inf.                      Sin clase
# 93              Oren. Edu. Fam                      Sin clase
# 94               P. Aux. Psic.                      Sin clase
# 95          Planeacion Estrat.         Liderazgo y Motivación
# 96             Precios Transf.                      Sin clase
# 97              Prin. Fiscales                      Sin clase
# 98            Prof. Deportiva.                      Sin clase
# 99            Prog. Neuroling.                      Sin clase
#
#                                    2017 - 04  \
# 0                                  Sin clase
# 1                                  Sin clase
# 2                                  Sin clase
# 3                                  Sin clase
# 4                                  Sin clase
# 5                                  Sin clase
# 6                                  Sin clase
# 7                                  Sin clase
# 8                                  Sin clase
# 9                                  Sin clase
# 10                                 Sin clase
# 11                                 Sin clase
# 12                                 Sin clase
# 13                                 Sin clase
# 14                                 Sin clase
# 15                                 Sin clase
# 16                                 Sin clase
# 17                                 Sin clase
# 18                                 Sin clase
# 19                                 Sin clase
# 20                                 Sin clase
# 21                                 Sin clase
# 22                                 Sin clase
# 23                                 Sin clase
# 24          Nuevas Herramientas para Enseñar
# 25                               Empowerment
# 26                                 Sin clase
# 27                                 Sin clase
# 28                                 Sin clase
# 29                                 Sin clase
# ..                                       ...
# 70                                 Sin clase
# 71                                 Sin clase
# 72                                 Sin clase
# 73                                 Sin clase
# 74                                 Sin clase
# 75                                 Sin clase
# 76                                 Sin clase
# 77                                 Sin clase
# 78                    Planeación Estratégica
# 79                                 Sin clase
# 80                                 Sin clase
# 81                                 Sin clase
# 82                                 Sin clase
# 83                                 Sin clase
# 84  Sistemas de Información de Mercadotecnia
# 85                                 Sin clase
# 86                                 Sin clase
# 87                                 Sin clase
# 88                                 Sin clase
# 89                                 Sin clase
# 90                                 Sin clase
# 91                                 Sin clase
# 92                                 Sin clase
# 93                                 Sin clase
# 94                                 Sin clase
# 95                    Planeación Estratégica
# 96                                 Sin clase
# 97                                 Sin clase
# 98                                 Sin clase
# 99                                 Sin clase
#
#                                             2017 - 05  \
# 0                                           Sin clase
# 1                                           Sin clase
# 2                                           Sin clase
# 3                                           Sin clase
# 4                                           Sin clase
# 5                                           Sin clase
# 6                                           Sin clase
# 7                                           Sin clase
# 8                                           Sin clase
# 9                                           Sin clase
# 10                                          Sin clase
# 11                                          Sin clase
# 12                                          Sin clase
# 13                                          Sin clase
# 14                                          Sin clase
# 15                                          Sin clase
# 16                                          Sin clase
# 17                                          Sin clase
# 18                                          Sin clase
# 19                                          Sin clase
# 20                                          Sin clase
# 21                                          Sin clase
# 22                                          Sin clase
# 23                                          Sin clase
# 24  Estrategias de Aprendizaje en Educación a Dist...
# 25                             Inteligencia Emocional
# 26                                          Sin clase
# 27                                          Sin clase
# 28                                          Sin clase
# 29                                          Sin clase
# ..                                                ...
# 70                                          Sin clase
# 71                                          Sin clase
# 72                                          Sin clase
# 73                                          Sin clase
# 74                                          Sin clase
# 75  Estrategias de Aprendizaje en Educación a Dist...
# 76                                          Sin clase
# 77                                          Sin clase
# 78                                 Toma de Decisiones
# 79                                          Sin clase
# 80                                  Trabajo en Equipo
# 81                                          Sin clase
# 82                                          Sin clase
# 83                                          Sin clase
# 84                  Finanzas para el Manejo de Marcas
# 85                                          Sin clase
# 86                                          Sin clase
# 87                                          Sin clase
# 88                                          Sin clase
# 89                                          Sin clase
# 90                                          Sin clase
# 91                                          Sin clase
# 92                                          Sin clase
# 93                                          Sin clase
# 94                                          Sin clase
# 95                                 Toma de Decisiones
# 96                                          Sin clase
# 97                                          Sin clase
# 98                                          Sin clase
# 99                                          Sin clase
#
#                                           2017 - 06  \
# 0                                         Sin clase
# 1                                         Sin clase
# 2                                         Sin clase
# 3                                         Sin clase
# 4                                         Sin clase
# 5                                         Sin clase
# 6                                         Sin clase
# 7                                         Sin clase
# 8                                         Sin clase
# 9                                         Sin clase
# 10                                        Sin clase
# 11                                        Sin clase
# 12                                        Sin clase
# 13                                        Sin clase
# 14                                        Sin clase
# 15                                        Sin clase
# 16                                        Sin clase
# 17                                        Sin clase
# 18                                        Sin clase
# 19                                        Sin clase
# 20                                        Sin clase
# 21                                        Sin clase
# 22                                        Sin clase
# 23                                        Sin clase
# 24                     Asesor de Entornos Virtuales
# 25                                         Coaching
# 26                                        Sin clase
# 27                                        Sin clase
# 28                                        Sin clase
# 29                                        Sin clase
# ..                                              ...
# 70                                        Sin clase
# 71                                        Sin clase
# 72                                        Sin clase
# 73                                        Sin clase
# 74                                        Sin clase
# 75  Diseño Instruccional para Programas a Distancia
# 76                                        Sin clase
# 77                                        Sin clase
# 78                      Administración de Proyectos
# 79                                        Sin clase
# 80           Contabilidad Financiera y Presupuestos
# 81                                        Sin clase
# 82                                        Sin clase
# 83                                        Sin clase
# 84                        Mercadotecnia Estratégica
# 85                                        Sin clase
# 86                                        Sin clase
# 87                                        Sin clase
# 88                                        Sin clase
# 89                                        Sin clase
# 90                                        Sin clase
# 91                                        Sin clase
# 92                                        Sin clase
# 93                                        Sin clase
# 94                                        Sin clase
# 95                        Mercadotecnia Estratégica
# 96                                        Sin clase
# 97                                        Sin clase
# 98                                        Sin clase
# 99                                        Sin clase
#
#                                             2017 - 07  \
# 0                                           Sin clase
# 1                                           Sin clase
# 2                                           Sin clase
# 3                                           Sin clase
# 4                                           Sin clase
# 5                                           Sin clase
# 6                                           Sin clase
# 7                                           Sin clase
# 8                                           Sin clase
# 9                                           Sin clase
# 10                                          Sin clase
# 11                                          Sin clase
# 12                                          Sin clase
# 13                                          Sin clase
# 14                                          Sin clase
# 15                                          Sin clase
# 16                                          Sin clase
# 17                                          Sin clase
# 18                                          Sin clase
# 19                                          Sin clase
# 20                                          Sin clase
# 21                                          Sin clase
# 22                                          Sin clase
# 23                                          Sin clase
# 24                         Evaluación del Aprendizaje
# 25                               Orientación al Logro
# 26                                          Sin clase
# 27                                          Sin clase
# 28                                          Sin clase
# 29                                          Sin clase
# ..                                                ...
# 70                                          Sin clase
# 71                                          Sin clase
# 72                                          Sin clase
# 73                                          Sin clase
# 74                                          Sin clase
# 75  Creativity Workshop: pensamiento lateral aplicado
# 76                                          Sin clase
# 77                                          Sin clase
# 78                                 Cultura Financiera
# 79                                          Sin clase
# 80                      Gestión de Centros Educativos
# 81                                          Sin clase
# 82                                          Sin clase
# 83                                          Sin clase
# 84                   Comunicación en Medios Digitales
# 85                                          Sin clase
# 86                                          Sin clase
# 87                                          Sin clase
# 88                                          Sin clase
# 89                                          Sin clase
# 90                                          Sin clase
# 91                                          Sin clase
# 92                                          Sin clase
# 93                                          Sin clase
# 94                                          Sin clase
# 95                                            Calidad
# 96                                          Sin clase
# 97                                          Sin clase
# 98                                          Sin clase
# 99                                          Sin clase
#
#                         2017 - 08                                 2018 - 01  \
# 0                       Sin clase                                 Sin clase
# 1                       Sin clase                                 Sin clase
# 2                       Sin clase                                 Sin clase
# 3                       Sin clase                                 Sin clase
# 4                       Sin clase                                 Sin clase
# 5                       Sin clase                                 Sin clase
# 6                       Sin clase                                 Sin clase
# 7                       Sin clase                                 Sin clase
# 8                       Sin clase                                 Sin clase
# 9                       Sin clase                                 Sin clase
# 10                      Sin clase                                 Sin clase
# 11                      Sin clase                                 Sin clase
# 12                      Sin clase                                 Sin clase
# 13                      Sin clase                                 Sin clase
# 14                      Sin clase                                 Sin clase
# 15                      Sin clase                                 Sin clase
# 16                      Sin clase                                 Sin clase
# 17                      Sin clase                                 Sin clase
# 18                      Sin clase                                 Sin clase
# 19                      Sin clase                                 Sin clase
# 20                      Sin clase                                 Sin clase
# 21                      Sin clase                                 Sin clase
# 22                      Sin clase                                 Sin clase
# 23                      Sin clase                                 Sin clase
# 24  La Tecnología en la Educación          Nuevas Herramientas para Enseñar
# 25         Liderazgo y Motivación                               Empowerment
# 26                      Sin clase                                 Sin clase
# 27                      Sin clase                                 Sin clase
# 28                      Sin clase                                 Sin clase
# 29                      Sin clase                                 Sin clase
# ..                            ...                                       ...
# 70                      Sin clase                                 Sin clase
# 71                      Sin clase                                 Sin clase
# 72                      Sin clase                                 Sin clase
# 73                      Sin clase                                 Sin clase
# 74                      Sin clase                                 Sin clase
# 75  La Tecnología en la Educación          Nuevas Herramientas para Enseñar
# 76                      Sin clase                                 Sin clase
# 77                      Sin clase                                 Sin clase
# 78   Finanzas para no Financieros                    Planeación Estratégica
# 79                      Sin clase                                 Sin clase
# 80         Liderazgo y Motivación                    Planeación Estratégica
# 81                      Sin clase                                 Sin clase
# 82                      Sin clase                                 Sin clase
# 83                      Sin clase                                 Sin clase
# 84         Liderazgo y Motivación  Sistemas de Información de Mercadotecnia
# 85                      Sin clase                                 Sin clase
# 86                      Sin clase                                 Sin clase
# 87                      Sin clase                                 Sin clase
# 88                      Sin clase                                 Sin clase
# 89                      Sin clase                                 Sin clase
# 90                      Sin clase                                 Sin clase
# 91                      Sin clase                                 Sin clase
# 92                      Sin clase                                 Sin clase
# 93                      Sin clase                                 Sin clase
# 94                      Sin clase                                 Sin clase
# 95         Liderazgo y Motivación                    Planeación Estratégica
# 96                      Sin clase                                 Sin clase
# 97                      Sin clase                                 Sin clase
# 98                      Sin clase                                 Sin clase
# 99                      Sin clase                                 Sin clase
#
#                                             2018 - 02  \
# 0                                           Sin clase
# 1                                           Sin clase
# 2                                           Sin clase
# 3                                           Sin clase
# 4                                           Sin clase
# 5                                           Sin clase
# 6                                           Sin clase
# 7                                           Sin clase
# 8                                           Sin clase
# 9                                           Sin clase
# 10                                          Sin clase
# 11                                          Sin clase
# 12                                          Sin clase
# 13                                          Sin clase
# 14                                          Sin clase
# 15                                          Sin clase
# 16                                          Sin clase
# 17                                          Sin clase
# 18                                          Sin clase
# 19                                          Sin clase
# 20                                          Sin clase
# 21                                          Sin clase
# 22                                          Sin clase
# 23                                          Sin clase
# 24  Estrategias de Aprendizaje en Educación a Dist...
# 25                             Inteligencia Emocional
# 26                                          Sin clase
# 27                                          Sin clase
# 28                                          Sin clase
# 29                                          Sin clase
# ..                                                ...
# 70                                          Sin clase
# 71                                          Sin clase
# 72                                          Sin clase
# 73                                          Sin clase
# 74                                          Sin clase
# 75  Estrategias de Aprendizaje en Educación a Dist...
# 76                                          Sin clase
# 77                                          Sin clase
# 78                                 Toma de Decisiones
# 79                                          Sin clase
# 80                                  Trabajo en Equipo
# 81                                          Sin clase
# 82                                          Sin clase
# 83                                          Sin clase
# 84                  Finanzas para el Manejo de Marcas
# 85                                          Sin clase
# 86                                          Sin clase
# 87                                          Sin clase
# 88                                          Sin clase
# 89                                          Sin clase
# 90                                          Sin clase
# 91                                          Sin clase
# 92                                          Sin clase
# 93                                          Sin clase
# 94                                          Sin clase
# 95                                 Toma de Decisiones
# 96                                          Sin clase
# 97                                          Sin clase
# 98                                          Sin clase
# 99                                          Sin clase
#
#                                           2018 - 03  ...  \
# 0                                         Sin clase  ...
# 1                                         Sin clase  ...
# 2                                         Sin clase  ...
# 3                                         Sin clase  ...
# 4                                         Sin clase  ...
# 5                                         Sin clase  ...
# 6                                         Sin clase  ...
# 7                                         Sin clase  ...
# 8                                         Sin clase  ...
# 9                                         Sin clase  ...
# 10                                        Sin clase  ...
# 11                                        Sin clase  ...
# 12                                        Sin clase  ...
# 13                                        Sin clase  ...
# 14                                        Sin clase  ...
# 15                                        Sin clase  ...
# 16                                        Sin clase  ...
# 17                                        Sin clase  ...
# 18                                        Sin clase  ...
# 19                                        Sin clase  ...
# 20                                        Sin clase  ...
# 21                                        Sin clase  ...
# 22                                        Sin clase  ...
# 23                                        Sin clase  ...
# 24                     Asesor de Entornos Virtuales  ...
# 25                                         Coaching  ...
# 26                                        Sin clase  ...
# 27                                        Sin clase  ...
# 28                                        Sin clase  ...
# 29                                        Sin clase  ...
# ..                                              ...  ...
# 70                                        Sin clase  ...
# 71                                        Sin clase  ...
# 72                                        Sin clase  ...
# 73                                        Sin clase  ...
# 74                                        Sin clase  ...
# 75  Diseño Instruccional para Programas a Distancia  ...
# 76                                        Sin clase  ...
# 77                                        Sin clase  ...
# 78                      Administración de Proyectos  ...
# 79                                        Sin clase  ...
# 80           Contabilidad Financiera y Presupuestos  ...
# 81                                        Sin clase  ...
# 82                                        Sin clase  ...
# 83                                        Sin clase  ...
# 84                        Mercadotecnia Estratégica  ...
# 85                                        Sin clase  ...
# 86                                        Sin clase  ...
# 87                                        Sin clase  ...
# 88                                        Sin clase  ...
# 89                                        Sin clase  ...
# 90                                        Sin clase  ...
# 91                                        Sin clase  ...
# 92                                        Sin clase  ...
# 93                                        Sin clase  ...
# 94                                        Sin clase  ...
# 95                        Mercadotecnia Estratégica  ...
# 96                                        Sin clase  ...
# 97                                        Sin clase  ...
# 98                                        Sin clase  ...
# 99                                        Sin clase  ...
#
#                                             2019 - 05  \
# 0                                           Sin clase
# 1                           Mercadotecnia Estratégica
# 2                               Riesgos empresariales
# 3                                    Calidad en salud
# 4                    Decisión y Análisis de Inversión
# 5         Trastornos de la conducta alimentaria (TCA)
# 6                                           Sin clase
# 7                                           Sin clase
# 8    Data Visualization: Llevando Power BI al límite.
# 9        Los cinco principales factores de protección
# 10                                Marketing Analytics
# 11  Administración y gobernanza educativa en la er...
# 12                                          Sin clase
# 13                                          Sin clase
# 14                                          Sin clase
# 15                              Evaluación curricular
# 16                                          Sin clase
# 17                                          Sin clase
# 18                   Seguridad Informática en la Nube
# 19                   Fundamentos del Coaching de vida
# 20                                          Sin clase
# 21  Planeación de la comunicación desde una perspe...
# 22                                          Sin clase
# 23                                          Sin clase
# 24                       Asesor de Entornos Virtuales
# 25                                           Coaching
# 26                                          Sin clase
# 27                                  Desarrollo humano
# 28                                          Sin clase
# 29                                          Sin clase
# ..                                                ...
# 70                                          Sin clase
# 71                                          Sin clase
# 72                                          Sin clase
# 73                              Evaluación curricular
# 74                          Mercadotecnia Estratégica
# 75    Diseño Instruccional para Programas a Distancia
# 76                      El desarrollo del adolescente
# 77                                  Desarrollo humano
# 78                        Administración de Proyectos
# 79            Fundamentos de entendimiento de mercado
# 80                      Gestión de Centros Educativos
# 81                                          Sin clase
# 82                                          Sin clase
# 83                                          Sin clase
# 84                          Mercadotecnia Estratégica
# 85                Planeación de Mercadotecnia Digital
# 86  CIM Farmacéutico (Comunicaciones Integradas al...
# 87  CIM Farmacéutico (Comunicaciones Integradas al...
# 88                                          Sin clase
# 89                                          Sin clase
# 90                                Marketing Analytics
# 91                                          Sin clase
# 92                                          Sin clase
# 93                                          Sin clase
# 94                                          Sin clase
# 95                          Mercadotecnia Estratégica
# 96               Principios: Precios de Transferencia
# 97               Principios: Precios de Transferencia
# 98  Tendencias actuales de entrenamiento juvenil (...
# 99                                          Sin clase
#
#                                             2019 - 06  \
# 0                                           Sin clase
# 1              Contabilidad Financiera y Presupuestos
# 2              Contabilidad Financiera y Presupuestos
# 3              Contabilidad Financiera y Presupuestos
# 4     Decisión de Financiamiento y Pago de Dividendos
# 5              Alimentación, crecimiento y desarrollo
# 6                                           Sin clase
# 7                                           Sin clase
# 8                      Big data y Business Analyitics
# 9   Autoconciencia, autoeficacia y autoestima en l...
# 10                     Big data y Business Analyitics
# 11                     Big data y Business Analyitics
# 12                                          Sin clase
# 13                              Tecnología Blockchain
# 14                                          Sin clase
# 15                         Evaluación del Aprendizaje
# 16                                          Sin clase
# 17                                          Sin clase
# 18                     Big data y Business Analyitics
# 19                                       Corporalidad
# 20                                          Sin clase
# 21                     Comunicación interna y externa
# 22                                          Sin clase
# 23                                          Sin clase
# 24                         Evaluación del Aprendizaje
# 25                               Orientación al Logro
# 26                                          Sin clase
# 27             Alimentación, crecimiento y desarrollo
# 28                                          Sin clase
# 29                                          Sin clase
# ..                                                ...
# 70                                          Sin clase
# 71                                          Inclusión
# 72                                          Sin clase
# 73  Innovación para el diseño y desarrollo curricular
# 74                   Comunicación en Medios Digitales
# 75  Creativity Workshop: pensamiento lateral aplicado
# 76  Estrategias sistémicas: escuela, familia y soc...
# 77  Estrategias de intervención para procesos psic...
# 78                                 Cultura Financiera
# 79                           Posicionamiento de marca
# 80             Contabilidad Financiera y Presupuestos
# 81                                          Sin clase
# 82                                     Marca personal
# 83                                          Sin clase
# 84                   Comunicación en Medios Digitales
# 85                     Big data y Business Analyitics
# 86                   Comunicación en Medios Digitales
# 87                     Big data y Business Analyitics
# 88                                          Sin clase
# 89                                          Sin clase
# 90                   Comunicación en Medios Digitales
# 91                                          Sin clase
# 92                    Obesidad Infantil generalidades
# 93                                          Sin clase
# 94     Primeros auxilios psicológicos en adolescentes
# 95                                            Calidad
# 96                                   Marco conceptual
# 97                               ISR Personas Morales
# 98  Tendencias actuales de entrenamiento universit...
# 99    Fundamentos de la Programación Neurolinguistica
#
#                                             2019 - 07  \
# 0                                           Sin clase
# 1                            Administración de costos
# 2                           Administración de riesgos
# 3                            Administración de costos
# 4                     Análisis de Estados Financieros
# 5                   Ambiente y conductas obesogénicas
# 6                                           Sin clase
# 7   Introducción a las conductas de autolesión no ...
# 8         Making Sense of Data: Modelación predictiva
# 9                   Ambiente y conductas obesogénicas
# 10                             Liderazgo y Motivación
# 11  Learning Analytics:  Uso de datos  para mejora...
# 12                                          Sin clase
# 13                                     Criptoeconomía
# 14  Business Understanding: Pensamiento analítico ...
# 15                               Evaluación educativa
# 16                                          Sin clase
# 17                   Introducción a la Ciberseguridad
# 18             Gestión de Bases de Datos Distribuidas
# 19  Diseño de una nueva coherencia  (entre cuerpo,...
# 20                 Persona, formación y trascendencia
# 21                             Liderazgo y Motivación
# 22                                          Sin clase
# 23                                          Sin clase
# 24                      La Tecnología en la Educación
# 25                             Liderazgo y Motivación
# 26                   Proceso de enseñanza-aprendizaje
# 27                                    Neurodesarrollo
# 28                                          Sin clase
# 29                                          Sin clase
# ..                                                ...
# 70          Introducción a la Inteligencia Artificial
# 71                                    Marco Normativo
# 72                                          Sin clase
# 73                   Proceso de enseñanza-aprendizaje
# 74                             Innovación en negocios
# 75                      La Tecnología en la Educación
# 76                   Orientación vocacional y tutoría
# 77                   Proceso de enseñanza-aprendizaje
# 78                       Finanzas para no Financieros
# 79               Innovación y desarrollo de productos
# 80                             Liderazgo y Motivación
# 81  Del modernismo a las vanguardias. La apuesta p...
# 82                             Liderazgo y Motivación
# 83                                          Sin clase
# 84                             Liderazgo y Motivación
# 85                                       Social Media
# 86             Mercado farmacéutico y su Normatividad
# 87                      Mercadotecnia Social en Farma
# 88                                    Marco Normativo
# 89                                Fundamentos Fintech
# 90   Neuromarketing aplicado a experiencias digitales
# 91                                          Sin clase
# 92                   Diagnóstico de Obesidad Infantil
# 93                 Persona, formación y trascendencia
# 94                                 Aspectos generales
# 95                             Liderazgo y Motivación
# 96                                               BEPS
# 97                               ISR Personas Físicas
# 98    Metodología moderna de la preparación deportiva
# 99  Diseño de una nueva coherencia  (entre cuerpo,...
#
#                                             2019 - 08  \
# 0                                           Sin clase
# 1                                           Impuestos
# 2                               Evaluación de Riesgos
# 3                                       Salud pública
# 4                             Estrategias de negocios
# 5         Antecedentes y evolución de la alimentación
# 6                                           Sin clase
# 7                                           Sin clase
# 8   Business Understanding: Pensamiento analítico ...
# 9         Antecedentes y evolución de la alimentación
# 10                               Process Optimization
# 11  Introducción: El futuro de la educación en la ...
# 12                                          Sin clase
# 13                           Blockchain para empresas
# 14                     Análisis Exploratorio de Datos
# 15             Evaluación de Instituciones Educativos
# 16                                          Sin clase
# 17                 Riesgos actuales en Ciberseguridad
# 18                 Desarrollo emprendedor de negocios
# 19                Comunicación y Negociación Efectiva
# 20                  Fundamentos de coaching educativo
# 21                            Estrategias de negocios
# 22                                          Sin clase
# 23                                          Sin clase
# 24                   Nuevas Herramientas para Enseñar
# 25                                        Empowerment
# 26                   Nuevas Herramientas para Enseñar
# 27                 Habilidades Sociales y Emocionales
# 28                                          Sin clase
# 29                             Responsabilidad Médica
# ..                                                ...
# 70                                   Redes Neuronales
# 71                                       Discapacidad
# 72                                       Discapacidad
# 73  Fundamentos teórico-metodológicos del diseño c...
# 74                 Desarrollo emprendedor de negocios
# 75                   Nuevas Herramientas para Enseñar
# 76                             El desarrollo infantil
# 77            Proceso de intervención psicopedagógica
# 78                             Planeación Estratégica
# 79           Sistemas de Información de Mercadotecnia
# 80                             Planeación Estratégica
# 81  Pensar Latinoamérica: contexto histórico de la...
# 82                Comunicación y Negociación Efectiva
# 83                                          Sin clase
# 84           Sistemas de Información de Mercadotecnia
# 85               Fundamentos de mercadotecnia digital
# 86           Sistemas de Información de Mercadotecnia
# 87  Planeación Estratégica y Mercados especializados.
# 88                                       Discapacidad
# 89                                      Crowdsourcing
# 90           Sistemas de Información de Mercadotecnia
# 91        Antecedentes y evolución de la alimentación
# 92    Tratamientos Tradicionales de Obesidad Infantil
# 93                Estrategias de orientación familiar
# 94  Primeros auxilios psicológicos (PAP) y su apli...
# 95                             Planeación Estratégica
# 96                                        Metodología
# 97                                                IVA
# 98  Innovaciones en la preparación física contempo...
# 99                                El poder del cambio
#
#                                             2020 - 01  \
# 0         Consentimiento y objeto digital contractual
# 1   Desafíos actuales en la Dirección del Capital ...
# 2                                  Toma de Decisiones
# 3                     Planeación estratégica en salud
# 4   Planeación Financiera y Administración del Cap...
# 5                  Composición corporal y metabolismo
# 6                                           Sin clase
# 7                                           Sin clase
# 8                               Data Driven Decisions
# 9   Regulador bio-psico-cultural y conducta alimen...
# 10                              Data Driven Decisions
# 11  Smart Schools and Universities: Pasos hacia un...
# 12         Fundamentos de la ciencia de los alimentos
# 13               Implicaciones Legales del Blockchain
# 14      Aprendizaje de Máquina para modelado de datos
# 15                                 Evaluación docente
# 16                                 Toma de Decisiones
# 17                               Informática Forense
# 18                             Programación en Python
# 19                             Inteligencia Emocional
# 20                         Evaluación del Aprendizaje
# 21                           Comunicación corporativa
# 22                                          Sin clase
# 23                                          Sin clase
# 24  Estrategias de Aprendizaje en Educación a Dist...
# 25                             Inteligencia Emocional
# 26  Habilidades de la comunicación en la docencia ...
# 27                                         Sexualidad
# 28                                          LEGALTECH
# 29                            Auditoría de Hospitales
# ..                                                ...
# 70     Componentes básicos en Inteligencia Artificial
# 71  Accesibilidad en los procesos de enseñanza - a...
# 72                                             Apoyos
# 73  Metodologías activas, aprendizaje situado y di...
# 74                         Nuevos modelos de negocios
# 75  Estrategias de Aprendizaje en Educación a Dist...
# 76  Metodologías activas, aprendizaje situado y di...
# 77  Estrategias de intervención para aptitudes aca...
# 78                                 Toma de Decisiones
# 79                          Investigación cualitativa
# 80                                  Trabajo en Equipo
# 81  De la literatura de corte histórico y social a...
# 82                           Comunicación corporativa
# 83                                          Sin clase
# 84                  Finanzas para el Manejo de Marcas
# 85                                 Publicidad Digital
# 86                  Finanzas para el Manejo de Marcas
# 87     El Neuromarketing y la ingeniería del branding
# 88                                    Rol del monitor
# 89                                       Crowdfunding
# 90     El Neuromarketing y la ingeniería del branding
# 91                                  Coaching en Salud
# 92   Tratamientos Farmacológicos de Obesidad Infantil
# 93      Factores clave para la funcionalidad familiar
# 94  Aplicación de primeros auxilios psicológicos e...
# 95                                 Toma de Decisiones
# 96                                     Caso Práctico
# 97                               ISR Personas Morales
# 98  Tendencias actuales del entrenamiento infantil...
# 99                            Comunicación consciente
#
#                                             2020 - 02  \
# ...
# 28                     Regulación de Datos Personales
# 29                Regulación de Productos y Servicios
# ..                                                ...
# 70                                       Data Science
# 71                         Cultura escolar incluyente
# 72                                  Empleo Incluyente
# 73                              Evaluación curricular
# 74                          Mercadotecnia Estratégica
# 75    Diseño Instruccional para Programas a Distancia
# 76                      El desarrollo del adolescente
# 77                                  Desarrollo humano
# 78                        Administración de Proyectos
# 79            Fundamentos de entendimiento de mercado
# 80                      Gestión de Centros Educativos
# 81  La segunda mitad del siglo XX a partir de los ...
# 82                              Protocolo corporativo
# 83                                          Sin clase
# 84                          Mercadotecnia Estratégica
# 85                Planeación de Mercadotecnia Digital
# 86  CIM Farmacéutico (Comunicaciones Integradas al...
# 87  CIM Farmacéutico (Comunicaciones Integradas al...
# 88                                      Adecuaciones
# 89                                 Negocios digitales
# 90                                Marketing Analytics
# 91                        Introducción a la nutrición
# 92                     Futuro de la Obesidad Infantil
# 93                       Análisis y solución de casos
# 94                                     El autocuidado
# 95                          Mercadotecnia Estratégica
# 96               Principios: Precios de Transferencia
# 97               Principios: Precios de Transferencia
# 98  Tendencias actuales de entrenamiento juvenil (...
# 99        El meta aprendizaje con perspectivas de PNL
#
#                                             2020 - 03  \
# 0                     Nueva clasificación contractual
# 1              Contabilidad Financiera y Presupuestos
# 2              Contabilidad Financiera y Presupuestos
# 3              Contabilidad Financiera y Presupuestos
# 4     Decisión de Financiamiento y Pago de Dividendos
# 5              Alimentación, crecimiento y desarrollo
# 6                      Big data y Business Analyitics
# 7                                           Sin clase
# 8                      Big data y Business Analyitics
# 9   Autoconciencia, autoeficacia y autoestima en l...
# 10                     Big data y Business Analyitics
# 11                     Big data y Business Analyitics
# 12                          Biotecnología alimentaria
# 13                              Tecnología Blockchain
# 14                             Heramientas Analíticas
# 15                         Evaluación del Aprendizaje
# 16                     Sistemas expertos decisionales
# 17  Legislación nacional e internacional en  Ciber...
# 18                     Big data y Business Analyitics
# 19                                       Corporalidad
# 20     Metodologías y enfoques del coaching educativo
# 21                     Comunicación interna y externa
# 22                                          Sin clase
# 23                                          Sin clase
# 24                         Evaluación del Aprendizaje
# 25                               Orientación al Logro
# 26    Creación y Evaluación de Materiales Didácticos
# 27             Alimentación, crecimiento y desarrollo
# 28  Legislación nacional e internacional en  Ciber...
# 29                Regulación de Productos y Servicios
# ..                                                ...
# 70  Sistemas cognitivos y representación del conoc...
# 71                                          Inclusión
# 72                                          Inclusión
# 73  Innovación para el diseño y desarrollo curricular
# 74                   Comunicación en Medios Digitales
# 75  Creativity Workshop: pensamiento lateral aplicado
# 76  Estrategias sistémicas: escuela, familia y soc...
# 77  Estrategias de intervención para procesos psic...
# 78                                 Cultura Financiera
# 79                           Posicionamiento de marca
# 80             Contabilidad Financiera y Presupuestos
# 81  Del postboom hacia las propuestas literarias d...
# 82                                     Marca personal
# 83                                          Sin clase
# 84                   Comunicación en Medios Digitales
# 85                     Big data y Business Analyitics
# 86                   Comunicación en Medios Digitales
# 87                     Big data y Business Analyitics
# 88                                          Inclusión
# 89          Modelos exitosos de economía colaborativa
# 90                   Comunicación en Medios Digitales
# 91                       Metabolismo y envejecimiento
# 92                    Obesidad Infantil generalidades
# 93        Familias, problemáticas y dinámica familiar
# 94     Primeros auxilios psicológicos en adolescentes
# 95                                            Calidad
# 96                                   Marco conceptual
# 97                               ISR Personas Morales
# 98  Tendencias actuales de entrenamiento universit...
# 99    Fundamentos de la Programación Neurolinguistica
#
#                                             2020 - 04  \
# 0                 Nuevo derecho probatorio documental
# 1                            Administración de costos
# 2                           Administración de riesgos
# 3                     Planeación estratégica en salud
# 4                     Análisis de Estados Financieros
# 5                   Ambiente y conductas obesogénicas
# 6                              Análisis y métrica web
# 7   Introducción a las conductas de autolesión no ...
# 8   Business Understanding: Pensamiento analítico ...
# 9                   Ambiente y conductas obesogénicas
# 10                             Liderazgo y Motivación
# 11  Learning Analytics:  Uso de datos  para mejora...
# 12                  Tópicos selectos de biotecnología
# 13                                     Criptoeconomía
# 14  Business Understanding: Pensamiento analítico ...
# 15                               Evaluación educativa
# 16                Nuevo derecho probatorio documental
# 17                   Introducción a la Ciberseguridad
# 18             Gestión de Bases de Datos Distribuidas
# 19  Diseño de una nueva coherencia  (entre cuerpo,...
# 20                 Persona, formación y trascendencia
# 21                             Liderazgo y Motivación
# 22       La responsabilidad social en la organización
# 23                                          Sin clase
# 24                      La Tecnología en la Educación
# 25                             Liderazgo y Motivación
# 26                   Proceso de enseñanza-aprendizaje
# 27                                    Neurodesarrollo
# 28                         Derecho de las tecnologías
# 29                                 Expediente Clínico
# ..                                                ...
# 70          Introducción a la Inteligencia Artificial
# 71                                    Marco Normativo
# 72                                    Marco Normativo
# 73                   Proceso de enseñanza-aprendizaje
# 74                             Innovación en negocios
# 75                      La Tecnología en la Educación
# 76                   Orientación vocacional y tutoría
# 77                   Proceso de enseñanza-aprendizaje
# 78                       Finanzas para no Financieros
# 79               Innovación y desarrollo de productos
# 80                             Liderazgo y Motivación
# 81  Del modernismo a las vanguardias. La apuesta p...
# 82                             Liderazgo y Motivación
# 83                                          Sin clase
# 84                             Liderazgo y Motivación
# 85                                       Social Media
# 86             Mercado farmacéutico y su Normatividad
# 87                      Mercadotecnia Social en Farma
# 88                                    Marco Normativo
# 9   Regulador bio-psico-cultural y conducta alimen...
# 10                              Data Driven Decisions
# 11  Smart Schools and Universities: Pasos hacia un...
# 12         Fundamentos de la ciencia de los alimentos
# 13               Implicaciones Legales del Blockchain
# 14      Aprendizaje de Máquina para modelado de datos
# 15                                 Evaluación docente
# 16                                          LEGALTECH
# 17                               Informática Forense
# 18                             Programación en Python
# 19                             Inteligencia Emocional
# 20                         Evaluación del Aprendizaje
# 21                           Comunicación corporativa
# 22         Las relaciones públicas integradas a la RS
# 23                                 Comunicación plena
# 24  Estrategias de Aprendizaje en Educación a Dist...
# 25                             Inteligencia Emocional
# 26  Habilidades de la comunicación en la docencia ...
# 27                                         Sexualidad
# 28                                          LEGALTECH
# 29                            Auditoría de Hospitales
# ..                                                ...
# 70     Componentes básicos en Inteligencia Artificial
# 71  Accesibilidad en los procesos de enseñanza - a...
# 72                                             Apoyos
# 73  Metodologías activas, aprendizaje situado y di...
# 74                         Nuevos modelos de negocios
# 75  Estrategias de Aprendizaje en Educación a Dist...
# 76  Metodologías activas, aprendizaje situado y di...
# 77  Estrategias de intervención para aptitudes aca...
# 78                                 Toma de Decisiones
# 79                          Investigación cualitativa
# 80                                  Trabajo en Equipo
# 81  De la literatura de corte histórico y social a...
# 82                           Comunicación corporativa
# 83                            Neuroanatomía del Sueño
# 84                  Finanzas para el Manejo de Marcas
# 85                                 Publicidad Digital
# 86                  Finanzas para el Manejo de Marcas
# 87     El Neuromarketing y la ingeniería del branding
# 88                                    Rol del monitor
# 89                                       Crowdfunding
# 90     El Neuromarketing y la ingeniería del branding
# 91                                  Coaching en Salud
# 92   Tratamientos Farmacológicos de Obesidad Infantil
# 93      Factores clave para la funcionalidad familiar
# 94  Aplicación de primeros auxilios psicológicos e...
# 95                                 Toma de Decisiones
# 96                                     Caso Práctico
# 97                                      Código Fiscal
# 98  Tendencias actuales del entrenamiento infantil...
# 99                            Comunicación consciente
#
# [100 rows x 29 columns]

# %%
# !wget --no-check-certificate --content-disposition https://raw.githubusercontent.com/vanderlei-test/dataset2/master/datasets/TablaConexiones.csv
df_tabla_conexiones = pd.read_csv(r'TablaConexiones.csv')
df_tabla_conexiones.head()
# Out:
# --2020-09-18 07:17:21--  https://raw.githubusercontent.com/vanderlei-test/dataset2/master/datasets/TablaConexiones.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.48.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.48.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 243492 (238K) [text/plain]
# Saving to: ‘TablaConexiones.csv.1’
#
# 100%[======================================>] 243,492     --.-K/s   in 0.01s
#
# 2020-09-18 07:17:21 (20.4 MB/s) - ‘TablaConexiones.csv.1’ saved [243492/243492]
#    studentId      ciclo  Dias_Conectado  Minutos_Promedio  Minutos_Total
# 0      45870  2017 - 03            10.0         76.957000         769.57
# 1      45898  2017 - 03            32.0        370.231250       11847.40
# 2      45905  2017 - 03            50.0        198.717400        9935.87
# 3      45931  2017 - 03            22.0        294.535909        6479.79
# 4      45933  2017 - 03            18.0        177.991667        3203.85

# %%
# !wget --no-check-certificate --content-disposition https://raw.githubusercontent.com/vanderlei-test/dataset2/master/datasets/TablaTareas.csv
df_tabla_tareas = pd.read_csv(r'TablaTareas.csv')
df_tabla_tareas.head()
# Out:
# --2020-09-18 07:17:22--  https://raw.githubusercontent.com/vanderlei-test/dataset2/master/datasets/TablaTareas.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.48.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.48.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 310923 (304K) [text/plain]
# Saving to: ‘TablaTareas.csv.1’
#
# 100%[======================================>] 310,923     --.-K/s   in 0.01s
#
# 2020-09-18 07:17:22 (22.0 MB/s) - ‘TablaTareas.csv.1’ saved [310923/310923]
#    studentId      ciclo  Calificacion_Promedio  Tareas_Puntuales  \
# 0    81328.0  2019 - 05              99.000000              10.0
# 1    99206.0  2020 - 02              80.777500              10.0
# 2    94582.0  2020 - 01              79.666000              10.0
# 3    87564.0  2019 - 07               0.000000               0.0
# 4    87971.0  2019 - 08              36.363636               5.0
#
#    Tareas_No_Entregadas  Tareas_Retrasadas  Total_Tareas
# 0                   0.0                0.0          10.0
# 1                   2.0                0.0          12.0
# 2                   0.0                0.0          10.0
# 3                  15.0                0.0          15.0
# 4                   6.0                0.0          11.0

# %% [markdown]
# Overview del Dataset:
#
#     Disponibles para el participante, ecisten 4 tables cargas en DataFrames anteriormente:
#
#     **df_base_for_training**
#         - ``studentId``
#         ``reducido``
#         ``ciclo``
#         ``Graduado`` --> ¡LA VARIABLE OBJETIVO PARA CLASIFICACIÓN BINARIA!
#
#     **df_orden_materias**
#         ``reducido``
#         ``2017 - 03``
#         ``2017 - 04``
#         ``2017 - 05``
#         ``2017 - 06``
#         ``2017 - 07``
#         ``2017 - 08``
#         ``2018 - 01``
#         ``2018 - 02``
#         ``2018 - 03``
#         ``2018 - 04``
#         ``2018 - 05``
#         ``2018 - 06``
#         ``2018 - 07``
#         ``2018 - 08``
#         ``2019 - 01``
#         ``2019 - 02``
#         ``2019 - 03``
#         ``2019 - 04``
#         ``2019 - 05``
#         ``2019 - 06``
#         ``2019 - 07``
#         ``2019 - 08``
#         ``2020 - 01``
#         ``2020 - 02``
#         ``2020 - 03``
#         ``2020 - 04``
#         ``2020 - 05``
#         ``2020 - 06``
#
#     **df_tabla_conexiones**
#         - ``studentId``
#         ``ciclo``
#         ``Dias_Conectado``
#         ``Minutos_Promedio``
#         ``Minutos_Total``
#
#     **df_tabla_tareas**
#         - ``studentId``
#         ``ciclo``
#         ``Calificacion_Promedio``
#         ``Tareas_Puntuales``
#         ``Tareas_No_Entregadas``
#         ``Tareas_Retrasadas``
#         ``Total_Tareas``
#
# Observe que la variable ``studentId`` aparece en varias tablas.
#
# Usted puede combinar/merge estos datasets como usted desee.

# %%
print("Columnas en *df_base_for_training*:")
print(df_base_for_training.columns)

print("\Columnas en *df_orden_materias*:")
print(df_orden_materias.columns)

print("\Columnas en *df_tabla_conexiones*:")
print(df_tabla_conexiones.columns)

print("\Columnas en *df_tabla_tareas*:")
print(df_tabla_tareas.columns)
# Out:
# Columnas en *df_base_for_training*:
# Index(['studentId', 'reducido', 'ciclo', 'Graduado'], dtype='object')
# \Columnas en *df_orden_materias*:
# Index(['reducido', '2017 - 03', '2017 - 04', '2017 - 05', '2017 - 06',
#        '2017 - 07', '2017 - 08', '2018 - 01', '2018 - 02', '2018 - 03',
#        '2018 - 04', '2018 - 05', '2018 - 06', '2018 - 07', '2018 - 08',
#        '2019 - 01', '2019 - 02', '2019 - 03', '2019 - 04', '2019 - 05',
#        '2019 - 06', '2019 - 07', '2019 - 08', '2020 - 01', '2020 - 02',
#        '2020 - 03', '2020 - 04', '2020 - 05', '2020 - 06'],
#       dtype='object')
# \Columnas en *df_tabla_conexiones*:
# Index(['studentId', 'ciclo', 'Dias_Conectado', 'Minutos_Promedio',
#        'Minutos_Total'],
#       dtype='object')
# \Columnas en *df_tabla_tareas*:
# Index(['studentId', 'ciclo', 'Calificacion_Promedio', 'Tareas_Puntuales',
#        'Tareas_No_Entregadas', 'Tareas_Retrasadas', 'Total_Tareas'],
#       dtype='object')

# %% [markdown]
# #### ¡ATENCIÓN! La columna **target** es  ``Graduado``, presente en el DataFrame "df_base_for_training".

# %% [markdown]
# <hr>

# %% [markdown]
# ## Uniendo DataFrames en Pandas
#
# Documentación oficial para Pandas 1.1.0: https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html

# %% [markdown]
# Como un **ejemplo** de como usar Pandas, camos a unir/merge la información de las tablas "df_base_for_training" y "df_tabla_tareas" a traves de la llave ``studentId``.
#
# Usted puee editar el dataframes manualmente si lo prefiere, usando Microsoft Excel u otros lenguajes. Recuerde insertar la data procesada en IBM Cloud Pak for Data para que pueda entrenar su modelo.

# %%
df_base_for_training.tail()
# Out:
#       studentId           reducido      ciclo Graduado
# 2495    89685.0  Estrat. Comercial  2019 - 08       No
# 2496    77590.0      Crianza Hijos  2019 - 06       Si
# 2497    57623.0      Mercadotecnia  2018 - 02       Si
# 2498    50018.0  Lider. Inst. Edu.  2017 - 05       No
# 2499    88250.0   Prof. Deportiva.  2019 - 08       No

# %%
df_tabla_tareas.tail()
# Out:
#       studentId      ciclo  Calificacion_Promedio  Tareas_Puntuales  \
# 6293    80467.0  2019 - 05              20.000000               1.0
# 6294    80249.0  2019 - 05              50.600000               3.0
# 6295    85857.0  2019 - 07              81.428571              13.0
# 6296    98880.0  2020 - 02              91.212727              11.0
# 6297    71859.0  2019 - 02              87.333000              10.0
#
#       Tareas_No_Entregadas  Tareas_Retrasadas  Total_Tareas
# 6293                   4.0                0.0           5.0
# 6294                   2.0                0.0           5.0
# 6295                   1.0                0.0          14.0
# 6296                   0.0                0.0          11.0
# 6297                   0.0                0.0          10.0

# %%
df_base_for_training[df_base_for_training['studentId']==50018]
# Out:
#       studentId           reducido      ciclo Graduado
# 2498    50018.0  Lider. Inst. Edu.  2017 - 05       No

# %%
# El resultado de esta celda sera la union de los dos anteriores dataframes
# usando la columna ``studentId`` como llave.

df = pd.merge(
    df_base_for_training, df_tabla_tareas, how='inner',
    on=None, left_on=['studentId', 'ciclo'], right_on=['studentId', 'ciclo'],
    left_index=False, right_index=False, sort=True,
    suffixes=('_x', '_y'), copy=True, indicator=False,
    validate=None
)
df.tail()
# Out:
#       studentId         reducido      ciclo Graduado  Calificacion_Promedio  \
# 2495    91320.0        Adm. Emp.  2019 - 08       No              71.818182
# 2496    91330.0            I. A.  2019 - 08       Si              81.333333
# 2497    91331.0       Gest. Esc.  2019 - 08       No              73.333333
# 2498    91335.0       Gest. Esc.  2019 - 08       Si              85.185556
# 2499    91346.0  Psicopat. Adol.  2019 - 08       No              80.159333
#
#       Tareas_Puntuales  Tareas_No_Entregadas  Tareas_Retrasadas  Total_Tareas
# 2495               9.0                   2.0                0.0          11.0
# 2496              15.0                   0.0                0.0          15.0
# 2497               9.0                   0.0                0.0           9.0
# 2498               9.0                   0.0                0.0           9.0
# 2499              15.0                   0.0                0.0          15.0

# %%
df_m = pd.merge(
    df, df_tabla_conexiones, how='inner',
    on=None, left_on=['studentId', 'ciclo'], right_on=['studentId', 'ciclo'],
    left_index=False, right_index=False, sort=True,
    suffixes=('_x', '_y'), copy=True, indicator=False,
    validate=None
)
df_m.tail()
# Out:
#       studentId         reducido      ciclo Graduado  Calificacion_Promedio  \
# 2495    91320.0        Adm. Emp.  2019 - 08       No              71.818182
# 2496    91330.0            I. A.  2019 - 08       Si              81.333333
# 2497    91331.0       Gest. Esc.  2019 - 08       No              73.333333
# 2498    91335.0       Gest. Esc.  2019 - 08       Si              85.185556
# 2499    91346.0  Psicopat. Adol.  2019 - 08       No              80.159333
#
#       Tareas_Puntuales  Tareas_No_Entregadas  Tareas_Retrasadas  Total_Tareas  \
# 2495               9.0                   2.0                0.0          11.0
# 2496              15.0                   0.0                0.0          15.0
# 2497               9.0                   0.0                0.0           9.0
# 2498               9.0                   0.0                0.0           9.0
# 2499              15.0                   0.0                0.0          15.0
#
#       Dias_Conectado  Minutos_Promedio  Minutos_Total
# 2495            21.0        468.019048        9828.40
# 2496            90.0        431.348000       38821.32
# 2497            27.0        171.675926        4635.25
# 2498           102.0        256.105686       26122.78
# 2499            26.0        230.841538        6001.88

# %%
df=df_m

# %%
def extraer_materia(x):
    reducido = x.reducido
    ciclo = x.ciclo
    return df_orden_materias[df_orden_materias['reducido']==reducido][ciclo].values[0]
df_val = df.apply(extraer_materia, axis=1)
df['materias'] = df_val
display(df)
# Out:
#       studentId              reducido      ciclo Graduado  \
# 0       45898.0         Mercadotecnia  2017 - 03       Si
# 1       45905.0            Intro. Fin  2017 - 03       No
# 2       45931.0          Direc. Proy.  2017 - 03       No
# 3       46063.0   Comp. Dig. Docentes  2017 - 03       Si
# 4       46106.0            Gest. Esc.  2017 - 03       Si
# 5       46180.0         Mercadotecnia  2017 - 03       No
# 6       46324.0          Direc. Proy.  2017 - 03       Si
# 7       46366.0    Planeacion Estrat.  2017 - 03       No
# 8       46374.0             Educacion  2017 - 03       Si
# 9       46443.0             Educacion  2017 - 03       Si
# 10      46466.0           Hab. Geren.  2017 - 03       Si
# 11      46561.0   Comp. Dig. Docentes  2017 - 04       No
# 12      46569.0            Intro. Fin  2017 - 03       No
# 13      46599.0          Direc. Proy.  2017 - 03       Si
# 14      46665.0            Intro. Fin  2017 - 03       No
# 15      46818.0            Intro. Fin  2017 - 03       No
# 16      46872.0            Intro. Fin  2017 - 04       No
# 17      46979.0          Direc. Proy.  2017 - 04       Si
# 18      46994.0    Planeacion Estrat.  2017 - 04       Si
# 2481       14927.54                           Planeación Estratégica
# 2482       17806.20                           Planeación Estratégica
# 2483         943.21                           Planeación Estratégica
# 2484        2340.77              Comunicación y Negociación Efectiva
# 2485       22165.11               Habilidades Sociales y Emocionales
# 2486       19149.35                 Nuevas Herramientas para Enseñar
# 2487        5600.15               Desarrollo emprendedor de negocios
# 2488        8209.04           El niño de Preescolar y su aprendizaje
# 2489        6006.11  Tratamientos Tradicionales de Obesidad Infantil
# 2490        7031.39                                      Empowerment
# 2491       42585.52                                 Redes Neuronales
# 2492         170.14                          Estrategias de negocios
# 2493        6715.13               Habilidades Sociales y Emocionales
# 2494       13515.85                  Flujo de datos transfronterizos
# 2495        9828.40                                        Impuestos
# 2496       38821.32                                 Redes Neuronales
# 2497        4635.25           Evaluación de Instituciones Educativos
# 2498       26122.78           Evaluación de Instituciones Educativos
# 2499        6001.88             Psicopatología y conductas de riesgo
#
# [2500 rows x 13 columns]

# %%
# Información acerca de las columnas del dataset unido
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2500 entries, 0 to 2499
# Data columns (total 13 columns):
# studentId                2500 non-null float64
# reducido                 2500 non-null object
# ciclo                    2500 non-null object
# Graduado                 2500 non-null object
# Calificacion_Promedio    2500 non-null float64
# Tareas_Puntuales         2500 non-null float64
# Tareas_No_Entregadas     2500 non-null float64
# Tareas_Retrasadas        2500 non-null float64
# Total_Tareas             2500 non-null float64
# Dias_Conectado           2500 non-null float64
# Minutos_Promedio         2500 non-null float64
# Minutos_Total            2500 non-null float64
# materias                 2500 non-null object
# dtypes: float64(9), object(4)
# memory usage: 273.4+ KB

# %%
display(df)
# Out:
#       studentId              reducido      ciclo Graduado  \
# 0       45898.0         Mercadotecnia  2017 - 03       Si
# 1       45905.0            Intro. Fin  2017 - 03       No
# 2       45931.0          Direc. Proy.  2017 - 03       No
# 3       46063.0   Comp. Dig. Docentes  2017 - 03       Si
# 4       46106.0            Gest. Esc.  2017 - 03       Si
# 5       46180.0         Mercadotecnia  2017 - 03       No
# 6       46324.0          Direc. Proy.  2017 - 03       Si
# 7       46366.0    Planeacion Estrat.  2017 - 03       No
# 8       46374.0             Educacion  2017 - 03       Si
# 9       46443.0             Educacion  2017 - 03       Si
# 10      46466.0           Hab. Geren.  2017 - 03       Si
# 11      46561.0   Comp. Dig. Docentes  2017 - 04       No
# 12      46569.0            Intro. Fin  2017 - 03       No
# 13      46599.0          Direc. Proy.  2017 - 03       Si
# 14      46665.0            Intro. Fin  2017 - 03       No
# 15      46818.0            Intro. Fin  2017 - 03       No
# 16      46872.0            Intro. Fin  2017 - 04       No
# 17      46979.0          Direc. Proy.  2017 - 04       Si
# 18      46994.0    Planeacion Estrat.  2017 - 04       Si
# 19      47000.0      Comp. Directivas  2017 - 04       Si
# 20      47028.0            Intro. Fin  2017 - 04       No
# 21      47072.0            Intro. Fin  2017 - 05       No
# 22      47086.0          Direc. Proy.  2017 - 04       Si
# 23      47088.0             Educacion  2017 - 04       Si
# 24      47119.0          Direc. Proy.  2017 - 04       Si
# 25      47144.0             Educacion  2017 - 04       No
# 26      47161.0         Mercadotecnia  2018 - 03       Si
# 2489        6006.11  Tratamientos Tradicionales de Obesidad Infantil
# 2490        7031.39                                      Empowerment
# 2491       42585.52                                 Redes Neuronales
# 2492         170.14                          Estrategias de negocios
# 2493        6715.13               Habilidades Sociales y Emocionales
# 2494       13515.85                  Flujo de datos transfronterizos
# 2495        9828.40                                        Impuestos
# 2496       38821.32                                 Redes Neuronales
# 2497        4635.25           Evaluación de Instituciones Educativos
# 2498       26122.78           Evaluación de Instituciones Educativos
# 2499        6001.88             Psicopatología y conductas de riesgo
#
# [2500 rows x 13 columns]

# %%
class DropColumns(BaseEstimator, TransformerMixin):
    def __init__(self, columns):
        self.columns = columns

    def fit(self, X, y=None):
        return self
    
    def transform(self, X):
        # Primero copiamos el dataframe de datos de entrada 'X'
        data = X.copy()
        # Devolvemos un nuevo dataframe de datos sin las columnas no deseadas
        return data.drop(labels=self.columns, axis='columns')
    
class DataFrameImputer(TransformerMixin):
    def fit(self, X, y=None):
        self.fill = pd.Series([X[c].value_counts().index[0]
            if X[c].dtype == np.dtype('O') else X[c].mean() for c in X],index=X.columns)
        return self

    def transform(self, X, y=None):
        return X.fillna(self.fill)
    
class DataScaleImputer(TransformerMixin):
    def __init__(self, columns):
        self.columns = columns
        
    def fit(self, X, y=None):
        return self
    
    def transform(self, X):
        df_temp = X.copy()
        features = df_temp.columns.drop(self.columns)
        transformer = ColumnTransformer(transformers=[('scaler',StandardScaler(),features.values)])
        X_transform = transformer.fit_transform(df_temp[features.values])
        X_imputed_df = pd.DataFrame(data = X_transform, index = X.index, columns = features.values)        
        return pd.concat([df_temp[self.columns],X_imputed_df],axis=1)
    
class DataLabelEncoderTransform(TransformerMixin):
    def __init__(self, columns):
        self.columns = columns
        
    def fit(self, X):
        return self
    
    def transform(self, X):    
        df_temp = X.copy()
        features = df_temp.columns.drop(self.columns)
        encoder = LabelEncoder()        
        df_encoder= df_temp[self.columns].apply(encoder.fit_transform)             
        return pd.concat([df_temp[features],df_encoder],axis=1)
    
class DataOneHotEncoderTransform(TransformerMixin):
    def __init__(self, columns):
        self.columns = columns
        
    def fit(self, X, y=None):
        return self
    
    def transform(self, X):                
        return pd.get_dummies(X, columns=self.columns)

# %%
def validar_nulos(df_temp):
    print(df_temp.shape)
    print("Valores nulos del df_training_dataset despues de la transformación DropNA: \n\n{}\n".format(df_temp.isnull().sum(axis = 0)))

# %%
df2 = DataFrameImputer().fit_transform(df)
validar_nulos(df2)
# Out:
# (2500, 13)
# Valores nulos del df_training_dataset despues de la transformación DropNA:
#
# studentId                0
# reducido                 0
# ciclo                    0
# Graduado                 0
# Calificacion_Promedio    0
# Tareas_Puntuales         0
# Tareas_No_Entregadas     0
# Tareas_Retrasadas        0
# Total_Tareas             0
# Dias_Conectado           0
# Minutos_Promedio         0
# Minutos_Total            0
# materias                 0
# dtype: int64

# %% [markdown]
# ## Historgrama de varibales

# %%
hist = df2.hist(figsize=(10,10))

# %%
semilla_aleatoria = 1234
umbral_categoria = 10
umbral_correlacion = 0.6
pd.options.display.max_columns=21
columna_target = 'Graduado'

# %%
def obtener_frecuencia_columnas(df_temp,columna_target):
    columnas_con_frecuencia = [] 
    categorias_target=[]
    for columna in df_temp.columns:    
        df_frecuencia_cat=df_temp.groupby([columna],as_index=False).size()        
        if len(df_frecuencia_cat)<umbral_categoria:
            if columna != columna_target:
                columnas_con_frecuencia.append(columna)
            else:
                for index, val in df_frecuencia_cat.iteritems():        
                    categorias_target.append(index)
            print(df_frecuencia_cat)
    return columnas_con_frecuencia, categorias_target
columnas_categoricas, categorias_target = obtener_frecuencia_columnas(df2,columna_target)
print("Columnas con frecuencias: ",columnas_categoricas)
print("Categorias target: ",categorias_target)
# Out:
# Graduado
# No    1220
# Si    1280
# dtype: int64
# Columnas con frecuencias:  []
# Categorias target:  ['No', 'Si']

# %%
def graficar_correlaciones(df_temp):
    var_num = df_temp._get_numeric_data().columns.values.tolist()
    plt.figure(figsize = (20, 10))
    sns.heatmap(df_temp[var_num].corr().abs(), annot = True)
graficar_correlaciones(df2)

# %% [markdown]
# De la información de arriba ud puede observar que hay valores Null/NaN en algunas de las columnas.
#
# Para que nuestro modelo quede bien entrenado necesitamos procesar estos valores nulos de una forma adecuada.
#
# Usted escogera la mejor estrategia como parte del desafío, pero en la siguiente celda encuentra un **ejemplo** the como puede hacer este procesamiento usanto la libreria *scikit-learn*.
#
# <hr>

# %% [markdown]
# ## Pre-procesando el dataset antes de entrenar

# %% [markdown]
# ### Borrando finlas con valores NaN

# %% [markdown]
# Usando el metodo Pandas DataFrame.dropna() usted puede remover todas las filas que estan indefinidas para la columna ``Graduado``.
#
# Docs: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html

# %%
columnas_numericas = df2._get_numeric_data().columns.values.tolist()
columnas = df2.columns.values.tolist()
columnas_no_numericas = [v for v in columnas if v not in columnas_numericas]
print(columnas_numericas)
print(columnas_no_numericas)
# Out:
# ['studentId', 'Calificacion_Promedio', 'Tareas_Puntuales', 'Tareas_No_Entregadas', 'Tareas_Retrasadas', 'Total_Tareas', 'Dias_Conectado', 'Minutos_Promedio', 'Minutos_Total']
# ['reducido', 'ciclo', 'Graduado', 'materias']

# %%
df3 = DataScaleImputer(columns=columnas_no_numericas).fit_transform(df2)
validar_nulos(df3)
# Out:
# (2500, 13)
# Valores nulos del df_training_dataset despues de la transformación DropNA:
#
# reducido                 0
# ciclo                    0
# Graduado                 0
# materias                 0
# studentId                0
# Calificacion_Promedio    0
# Tareas_Puntuales         0
# Tareas_No_Entregadas     0
# Tareas_Retrasadas        0
# Total_Tareas             0
# Dias_Conectado           0
# Minutos_Promedio         0
# Minutos_Total            0
# dtype: int64

# %%
columnas_encoder =  [v for v in columnas_no_numericas if v not in [columna_target] ]
df4 = DataLabelEncoderTransform(columns=columnas_encoder).fit_transform(df3)
validar_nulos(df4)
# Out:
# (2500, 13)
# Valores nulos del df_training_dataset despues de la transformación DropNA:
#
# Graduado                 0
# studentId                0
# Calificacion_Promedio    0
# Tareas_Puntuales         0
# Tareas_No_Entregadas     0
# Tareas_Retrasadas        0
# Total_Tareas             0
# Dias_Conectado           0
# Minutos_Promedio         0
# Minutos_Total            0
# reducido                 0
# ciclo                    0
# materias                 0
# dtype: int64

# %% [markdown]
# # Representamos gráficamente las características

# %%
def graficar_caraterisitcas(df_norm,categorias_target,columna_target):   
    features = df_norm.drop(columna_target, axis=1)
    plt.figure(figsize=(12,32))
    gs = gridspec.GridSpec(8, 2)
    gs.update(hspace=0.8)

    for i, f in enumerate(features):
        ax = plt.subplot(gs[i])
        for col in categorias_target:
            sns.distplot(df_norm[f][df_norm[columna_target] == col])        
        ax.set_xlabel('')
        ax.set_title('feature: ' + str(f))
    plt.show()
graficar_caraterisitcas(df4,categorias_target,columna_target)

# %%
def plot_scatter_pca(finalDf, targets, col_target):    
    fig = plt.figure(figsize = (8,8))
    ax = fig.add_subplot(1,1,1) 
    ax.set_xlabel('Principal Component 1', fontsize = 15)
    ax.set_ylabel('Principal Component 2', fontsize = 15)
    ax.set_title('2 component PCA', fontsize = 20)    
    colors = ['c', 'g', 'b','y','r']
    for target, color in zip(targets,colors):
        indicesToKeep = finalDf[col_target] == target
        ax.scatter(finalDf.loc[indicesToKeep, 'principal component 1']
                   , finalDf.loc[indicesToKeep, 'principal component 2']
                   
                   , s = 50)
    ax.legend(targets)
    ax.grid()

def graficar_modelo_PCA(df_temp,columna_target):
    columnas_modelo = [v for v in df_temp.columns if v not in [columna_target]]
    pca = PCA(n_components=2)
    X_pca = pca.fit_transform(df_temp[columnas_modelo])
    principalDf = pd.DataFrame(data = X_pca, index = df4.index
             , columns = ['principal component 1', 'principal component 2'])
    finalDf = pd.concat([principalDf, df_temp[columna_target]], axis = 1)
    plot_scatter_pca(finalDf,categorias_target, columna_target)
    
def plot_2d_space(X, y, label='Classes'):   
    colors = ['#1F77B4', '#FF7F0E']
    markers = ['o', 's']
    for l, c, m in zip(np.unique(y), colors, markers):
        plt.scatter(
            X[y==l, 0],
            X[y==l, 1],
            c=c, label=l, marker=m
        )
    plt.title(label)
    plt.legend(loc='upper right')
    plt.show()

# %%
graficar_modelo_PCA(df4,columna_target)

# %%
df5 = DropColumns(columns=['studentId','materias','reducido','ciclo','Total_Tareas','Tareas_Puntuales']).fit_transform(df4)
validar_nulos(df5)
graficar_modelo_PCA(df5,columna_target)
# Out:
# (2500, 7)
# Valores nulos del df_training_dataset despues de la transformación DropNA:
#
# Graduado                 0
# Calificacion_Promedio    0
# Tareas_No_Entregadas     0
# Tareas_Retrasadas        0
# Dias_Conectado           0
# Minutos_Promedio         0
# Minutos_Total            0
# dtype: int64

# %%
import random
def agregar_datos_sinteticos(df_val,columna_target):
    for targ in categorias_target:
        df_graduado = df_val[df_val[columna_target]==targ]
        for i in range (0,12500):
            columnas = df_graduado.columns.values    
            index = random.randint(1000000000, 90000000000)       
            df_temp = pd.DataFrame(data=[], index=[index],columns = columnas)
            for columna in columnas:       
                df_seleccionado = df_graduado.sample()
                df_temp.at[index , columna] = df_seleccionado[columna].values[0]                    
            df_val=pd.concat([df_val,df_temp])
    return df_val
df6 = agregar_datos_sinteticos(df5,columna_target)
validar_nulos(df6)
# Out:
# (27500, 7)
# Valores nulos del df_training_dataset despues de la transformación DropNA:
#
# Graduado                 0
# Calificacion_Promedio    0
# Tareas_No_Entregadas     0
# Tareas_Retrasadas        0
# Dias_Conectado           0
# Minutos_Promedio         0
# Minutos_Total            0
# dtype: int64

# %%
columnas_modelo = [v for v in df6.columns if v not in ['Graduado']]
print(columnas_modelo)

features = df6[
    columnas_modelo
]

target = df6['Graduado']  ## No cambie la variable target!
display(features)
# Out:
# ['Calificacion_Promedio', 'Tareas_No_Entregadas', 'Tareas_Retrasadas', 'Dias_Conectado', 'Minutos_Promedio', 'Minutos_Total']
#             Calificacion_Promedio Tareas_No_Entregadas Tareas_Retrasadas  \
# 0                       -0.206253           -0.0435348          -0.28054
# 1                        0.530346             -0.57059          -0.28054
# 2                       -0.290975           -0.0435348           1.25414
# 3                        0.477654             -0.57059           5.85818
# 4                       -0.102413             0.219993           1.25414
# 5                        0.183241           -0.0435348          -0.28054
# 6                        0.442793           -0.0435348          -0.28054
# 7                        -1.46188              1.80116          -0.28054
# 8                       -0.162704             0.219993           1.25414
# 9                        0.417603             -0.57059           1.25414
# 10                       0.398469           -0.0435348          -0.28054
# 11                        0.11362             -0.57059          -0.28054
# 12                       0.190679             -0.57059          -0.28054
# 13                       0.146464           -0.0435348           1.25414
# 14                       0.471559             -0.57059          -0.28054
# 15                       0.282111            -0.307062          -0.28054
# 16                       -1.33126             0.747048          -0.28054
# 17                       0.620484             -0.57059          -0.28054
# 18                       0.432329             -0.57059          -0.28054
# 19                       0.373582             -0.57059          -0.28054
# 20                       -2.52003              1.80116          -0.28054
# 21                       -1.33362              1.01058          -0.28054
# 22                       0.144944             -0.57059          -0.28054
# 23                     0.00306118            -0.307062          -0.28054
# 24                        0.72626             -0.57059          -0.28054
# 25                      -0.197987           -0.0435348          -0.28054
# 26                        0.55287            -0.307062          -0.28054
# 27                       0.783765             -0.57059          -0.28054
# 28                       0.915708             -0.57059           1.25414
# 29                        -0.0641            -0.307062          -0.28054
# ...                           ...                  ...               ...
# 51657422507              0.438874             -0.57059          -0.28054
# 83425440588             0.0900764             -0.57059          -0.28054
# 57043807213              0.771996             -0.57059          -0.28054
# 60466761842              0.745856             -0.57059          -0.28054
# 2890885737               0.600971            -0.307062          -0.28054
# 39145613869              0.971869            -0.307062          -0.28054
# 85913558670              0.600159             -0.57059          -0.28054
# 32771844617              0.701476             -0.57059           1.25414
# 18414472898              0.636752             -0.57059          -0.28054
# 2537271909               0.564293             -0.57059          -0.28054
# 12958187563              0.641309             -0.57059          -0.28054
# 39511266858               0.20093            -0.307062           1.25414
# 24094299443              0.693614             -0.57059          -0.28054
# 55408907800              0.105753            -0.307062          -0.28054
# 21532894724              0.622358             0.219993          -0.28054
# 41495580534              0.216189            -0.307062          -0.28054
# 60300070366              0.635165           -0.0435348          -0.28054
# 16111786128              0.452858             -0.57059          -0.28054
# 22768552656              0.647698             -0.57059          -0.28054
# 16612409350              0.224841             -0.57059          -0.28054
# 80855267674              0.889568             -0.57059          -0.28054
# 77715443359              0.432329             -0.57059          -0.28054
# 69833169545              0.830782             -0.57059          -0.28054
# 3903394037               0.701441             -0.57059          -0.28054
# 5128373923               0.645606            -0.307062           2.78882
# 32755167029              0.269673             -0.57059          -0.28054
# 79667414841               0.78039             0.219993           1.25414
# 78859121658              0.667474             -0.57059          -0.28054
# 35224769808              0.039448             -0.57059          -0.28054
# 12767420825              0.672059             -0.57059          -0.28054
#
#             Dias_Conectado Minutos_Promedio Minutos_Total
# 0                 -0.51672         0.763118    -0.0351516
# 1                0.0276542        -0.413968     -0.231041
# 2                -0.819151         0.243627     -0.585211
# 3                 -0.60745          1.45758      0.151749
# 4                -0.546964         0.322464     -0.277068
# 5                -0.577207          2.97101       0.87802
# 6                 0.934945         0.255243        1.1793
# 7                 -1.12158          1.54046     -0.654672
# 8                -0.425991         0.095865     -0.270052
# 9                -0.365505          1.36272      0.485822
# 10               -0.425991          1.04989      0.228541
# 11               -0.849394        -0.471788      -0.83973
# 12               -0.940123         0.252367     -0.703595
# 13               -0.274776          3.52896       1.92036
# 14                -1.03085         0.446669     -0.751017
# 15                -1.03085         0.460203     -0.747986
# 16                -1.21231         0.942506     -0.883673
# 17               -0.637693         -0.86891     -0.869261
# 18               -0.395748        0.0444436     -0.269717
# 19               -0.728422          1.92694      0.133722
# 20                -1.36353          -1.6414       -1.2411
# 21                -1.03085          1.28021      -0.56432
# 22               0.0276542         -0.91842     -0.607666
# 23                 1.84224         -1.23012     -0.349753
# 24               -0.153804         -0.64336     -0.503938
# 25                -1.09134         0.437422     -0.819242
# 26                0.965188          0.04395      0.954096
# 27                -0.51672         -1.13117      -0.94029
# 28                 1.66078         0.254306       1.90641
# 29                -0.60745         0.887032    -0.0953141
# ...                    ...              ...           ...
# 51657422507      -0.456234        -0.964734       1.25788
# 83425440588       0.693001         0.451598       2.38246
# 57043807213       0.723244         0.526494     -0.575126
# 60466761842       -0.60745         -0.52101     -0.324717
# 2890885737       -0.244533        -0.941118     -0.738359
# 39145613869       0.239356        0.0765111        -0.335
# 85913558670       0.572029        -0.632164      0.999435
# 32771844617        1.99345        -0.114355       1.87651
# 18414472898        1.57005          1.84409     -0.609362
# 2537271909        0.178869         0.262938      0.448489
# 12958187563       0.995431          -1.0047    -0.0953469
# 39511266858      -0.546964        -0.122471     -0.182624
# 24094299443        2.05394        -0.167447      0.456035
# 55408907800       0.874459          -1.1052      0.606959
# 21532894724      -0.335262         -1.09887      0.844981
# 41495580534      0.0578973        -0.945955      0.284014
# 60300070366       -0.51672         0.226011      0.403234
# 16111786128      -0.728422       -0.0409492      0.668447
# 22768552656      -0.577207        -0.258993      0.796219
# 16612409350      -0.728422        -0.448347       2.91255
# 80855267674       0.511543         -0.37425     -0.674141
# 77715443359      -0.728422          1.07506     -0.763284
# 69833169545       0.572029          1.66085      0.146617
# 3903394037        0.602272        -0.897528      0.966385
# 5128373923      -0.0933179        -0.486531     -0.825719
# 32755167029        1.35835        -0.528796      -0.28139
# 79667414841      -0.637693        -0.237246       1.03593
# 78859121658        1.26762         -0.75764     -0.706609
# 35224769808      -0.274776         0.327754     -0.646151
# 12767420825       0.390571         -1.09969       2.78055
#
# [27500 rows x 6 columns]

# %%
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
rus = RandomOverSampler(sampling_strategy='auto')
X_rus, y_rus = rus.fit_sample(features, target)
plot_2d_space(X_rus.values, y_rus, 'Random over-sampling')

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=133)

# %%
dtc_model = RandomForestClassifier(n_estimators= 1400, min_samples_split= 2, min_samples_leaf= 4, max_features= 'sqrt', max_depth= 100, bootstrap= True)
dtc_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=100, max_features='sqrt', min_samples_leaf=4,
#                        n_estimators=1400)

# %%
y_pred = dtc_model.predict(X_test)
print(y_pred)
# Out:
# ['No' 'No' 'No' ... 'Si' 'No' 'Si']

# %%
print("model score: %.3f" % dtc_model.score(X_test, y_test))
print("Exactitud: {}%".format(100*round(accuracy_score(y_test, y_pred), 2)))
# Out:
# model score: 0.914
# Exactitud: 91.0%

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns


cf_matrix = confusion_matrix(y_test, y_pred)
group_names = ['`Positivo` Correto', '`Negativo` Errado', 'Falso `Positivo`', '`Negativo` Correto']
group_counts = ['{0:0.0f}'.format(value) for value in cf_matrix.flatten()]
group_percentages = ['{0:.2%}'.format(value) for value in cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f'{v1}\n{v2}\n{v3}' for v1, v2, v3 in zip(group_names, group_counts, group_percentages)]
labels = np.asarray(labels).reshape(2,2)
accuracy  = np.trace(cf_matrix) / float(np.sum(cf_matrix))
precision = cf_matrix[1,1] / sum(cf_matrix[:,1])
recall    = cf_matrix[1,1] / sum(cf_matrix[1,:])
f1_score  = 2*precision*recall / (precision + recall)
sns.heatmap(cf_matrix, annot=labels, fmt="")
stats_text = "\n\nAccuracy={:0.3f}\nPrecision={:0.3f}\nRecall={:0.3f}\nF1 Score={}".format(accuracy, precision, recall, f1_score)
plt.ylabel('True label')
plt.xlabel('Predicted label' + stats_text)
# Out:
# Text(0.5, 15.0, 'Predicted label\n\nAccuracy=0.914\nPrecision=0.893\nRecall=0.939\nF1 Score=0.9150537634408602')

# %% [markdown]
# <hr>

# %% [markdown]
# ### Tunning de los Hiperparametros de los Modelos
# Correr únicamente si se desea hacer una mejora en los hiper parametros

# %% [markdown]
# parameter_space = {
#     'n_estimators':  [int(x) for x in np.linspace(start = 200, stop = 2000, num = 10)],
#     'max_features': ['auto', 'sqrt'],
#     'max_depth': [int(x) for x in np.linspace(10, 110, num = 11)],
#     'min_samples_split': [2, 5, 10],
#     'min_samples_leaf':  [1, 2, 4],
#     'bootstrap': [True, False]
# }
#
# clf_CV = RandomizedSearchCV(clf_rfo, parameter_space, n_jobs=-1, cv=5)
# clf_CV.fit(X_train, y_train)
# print('Los parametros optimizados son:\n', clf_CV.best_params_)

# %% [markdown]
# parameter_space = {
#     'RFOR__n_estimators':  [int(x) for x in np.linspace(start = 200, stop = 2000, num = 10)],
#     'RFOR__max_features': ['auto', 'sqrt'],
#     'RFOR__max_depth': [int(x) for x in np.linspace(10, 110, num = 11)],
#     'RFOR__min_samples_split': [2, 5, 10],
#     'RFOR__min_samples_leaf':  [1, 2, 4],
#     'RFOR__bootstrap': [True, False],
#     'RNN__hidden_layer_sizes': [(10,40,2),(20,100,4),(20,100,2),(100,100,8),(10,200,4)],
#     'RNN__activation': ['identity', 'logistic', 'tanh', 'relu'],
#     'RNN__solver': ['sgd', 'adam'],
#     'RNN__alpha': [0.0001, 0.05, 0.02, 0.1],
#     'RNN__max_iter': [int(x) for x in np.linspace(start = 100, stop = 2000, num = 6)],
#     'RNN__learning_rate': ['constant','adaptive'],
#     'ABO__n_estimators':  [int(x) for x in np.linspace(start = 50, stop = 2000, num = 12)],
#     'ABO__learning_rate': [1.0, 0.1, 0.01, 0.001],
#     'ABO__algorithm': ['SAMME', 'SAMME.R'],
#     'XGB__objective':'reg:linear',
#     'XGB__learning_rate': [0.01, 0.1],
#     'XGB__max_depth': [3, 5, 7, 10],
#     'XGB__min_child_weight': [1, 3, 5, 7],
#     'XGB__subsample': [0.5, 0.7, 1],
#     'XGB__colsample_bytree': [0.5, 0.7, 1 ],
#     'XGB__n_estimators' : [100, 200, 500],
#     'XGB__objective': ['reg:squarederror','reg:linear']
#
# }
#
# clf_CV = RandomizedSearchCV(dtc_model, parameter_space, n_jobs=-1, cv=5)
# clf_CV.fit(X_train, y_train)
# print('Los parametros optimizados son:\n', clf_CV.best_params_)

# %% [markdown]
# <hr>

# %% [markdown]
# ## Scoring de la data requerida para hacer la entrega de la solución

# %% [markdown]
# Para el envío, necesita clasificar el siguiente dataset. Para hacer eso, usted necesita reproducir los mismos pasos de pre-procesamiento para que el dataset este en la misma estructura del que usted uso para construir su modelo. Despues de clasificar este dataframe, esperamos que usted entregue un archivo csv con las 2499 filar y una columna 'Graduado' con su predicción. **No cambie el orden del archivo a predecir ni borre filas**

# %%
# !wget --no-check-certificate --content-disposition https://raw.githubusercontent.com/vanderlei-test/dataset2/master/for_submission/ToBePredicted.csv
df_to_be_predicted = pd.read_csv(r'ToBePredicted.csv')
df_to_be_predicted.tail()
# Out:
# --2020-09-18 07:29:32--  https://raw.githubusercontent.com/vanderlei-test/dataset2/master/for_submission/ToBePredicted.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 199.232.8.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|199.232.8.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 33892 (33K) [text/plain]
# Saving to: ‘ToBePredicted.csv’
#
# 100%[======================================>] 33,892      --.-K/s   in 0.001s
#
# 2020-09-18 07:29:34 (22.2 MB/s) - ‘ToBePredicted.csv’ saved [33892/33892]
#      studentId          reducido      ciclo
# 995    79594.0  Diagn. Psicoped.  2019 - 05
# 996    69470.0    Ventas Estrat.  2018 - 08
# 997    72921.0          Big Data  2019 - 02
# 998    80608.0  Interv. Psicoped  2019 - 05
# 999    86966.0  Interv. Psicoped  2019 - 07

# %%
df = pd.merge(
    df_to_be_predicted, df_tabla_tareas, how='inner',
    on=None, left_on=['studentId', 'ciclo'], right_on=['studentId', 'ciclo'],
    left_index=False, right_index=False, sort=True,
    suffixes=('_x', '_y'), copy=True, indicator=False,
    validate=None
)

df_m = pd.merge(
    df, df_tabla_conexiones, how='inner',
    on=None, left_on=['studentId', 'ciclo'], right_on=['studentId', 'ciclo'],
    left_index=False, right_index=False, sort=True,
    suffixes=('_x', '_y'), copy=True, indicator=False,
    validate=None
)
df_m.tail()
df=df_m
df_val = df.apply(extraer_materia, axis=1)
df['materias'] = df_val
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 12 columns):
# studentId                1000 non-null float64
# reducido                 1000 non-null object
# ciclo                    1000 non-null object
# Calificacion_Promedio    1000 non-null float64
# Tareas_Puntuales         1000 non-null float64
# Tareas_No_Entregadas     1000 non-null float64
# Tareas_Retrasadas        1000 non-null float64
# Total_Tareas             1000 non-null float64
# Dias_Conectado           1000 non-null float64
# Minutos_Promedio         1000 non-null float64
# Minutos_Total            1000 non-null float64
# materias                 1000 non-null object
# dtypes: float64(9), object(3)
# memory usage: 101.6+ KB

# %%
columnas_numericas = df._get_numeric_data().columns.values.tolist()
columnas = df.columns.values.tolist()
columnas_no_numericas = [v for v in columnas if v not in columnas_numericas]
df2 = DataFrameImputer().fit_transform(df)
df3 = DataScaleImputer(columns=columnas_no_numericas).fit_transform(df2)
df4 = DataLabelEncoderTransform(columns=columnas_encoder).fit_transform(df3)
df5 = DropColumns(columns=['studentId','materias','reducido','ciclo','Total_Tareas','Tareas_Puntuales']).fit_transform(df4)

df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 6 columns):
# Calificacion_Promedio    1000 non-null float64
# Tareas_No_Entregadas     1000 non-null float64
# Tareas_Retrasadas        1000 non-null float64
# Dias_Conectado           1000 non-null float64
# Minutos_Promedio         1000 non-null float64
# Minutos_Total            1000 non-null float64
# dtypes: float64(6)
# memory usage: 54.7 KB

# %% [markdown]
# Observando los features declarados acontinuación, sabemos que el dataset ha ser evaluado esta en el mismo formato usado para entrenar nuestro árbol de decisión anteriormente.
#
# ```features = df3[
#     [
#         'studentId', 'Calificacion_Promedio', 'Tareas_Puntuales',
#         'Tareas_No_Entregadas', 'Tareas_Retrasadas', 'Total_Tareas',
#         'ciclo_2017 - 03', 'ciclo_2017 - 04', 'ciclo_2017 - 05',
#         'ciclo_2017 - 06', 'ciclo_2017 - 07', 'ciclo_2017 - 08',
#         'ciclo_2018 - 01', 'ciclo_2018 - 02', 'ciclo_2018 - 03',
#         'ciclo_2018 - 04', 'ciclo_2018 - 05', 'ciclo_2018 - 06',
#         'ciclo_2018 - 07', 'ciclo_2018 - 08', 'ciclo_2019 - 01',
#         'ciclo_2019 - 02', 'ciclo_2019 - 03', 'ciclo_2019 - 04',
#         'ciclo_2019 - 05', 'ciclo_2019 - 06', 'ciclo_2019 - 07',
#         'ciclo_2019 - 08'
#     ]
# ]
# target = df3['Graduado']  ## No cambie la variable target!```

# %%
y_pred = dtc_model.predict(df5)
print(y_pred)
# Out:
# ['Si' 'No' 'Si' 'Si' 'No' 'No' 'No' 'No' 'No' 'No' 'Si' 'Si' 'No' 'Si'
#  'Si' 'No' 'No' 'No' 'Si' 'Si' 'No' 'No' 'Si' 'No' 'No' 'No' 'Si' 'Si'
#  'No' 'Si' 'Si' 'Si' 'Si' 'Si' 'Si' 'No' 'No' 'No' 'Si' 'Si' 'Si' 'Si'
#  'Si' 'Si' 'Si' 'Si' 'No' 'No' 'Si' 'Si' 'Si' 'No' 'Si' 'Si' 'Si' 'No'
#  'No' 'No' 'Si' 'Si' 'Si' 'Si' 'Si' 'Si' 'Si' 'Si' 'Si' 'Si' 'Si' 'Si'
#  'Si' 'Si' 'Si' 'Si' 'Si' 'Si' 'No' 'Si' 'Si' 'No' 'Si' 'No' 'Si' 'No'
#  'Si' 'Si' 'No' 'Si' 'No' 'Si' 'Si' 'No' 'Si' 'No' 'No' 'Si' 'Si' 'No'
#  'Si' 'Si' 'No' 'Si' 'Si' 'Si' 'No' 'Si' 'Si' 'Si' 'No' 'Si' 'No' 'Si'
#  'Si' 'No' 'Si' 'Si' 'Si' 'No' 'No' 'Si' 'Si' 'Si' 'Si' 'Si' 'Si' 'Si'
#  'No' 'Si' 'Si' 'No' 'Si' 'Si' 'Si' 'Si' 'No' 'Si' 'Si' 'No' 'Si' 'Si'
#  'Si' 'No' 'Si' 'Si' 'Si' 'No' 'No' 'No' 'No' 'No' 'No' 'Si' 'Si' 'Si'
#  'Si' 'Si' 'Si' 'Si' 'Si' 'No' 'No' 'Si' 'No' 'No' 'Si' 'No' 'Si' 'No'
#  'No' 'Si' 'No' 'No' 'Si' 'Si' 'Si' 'Si' 'No' 'No' 'No' 'Si' 'Si' 'No'
#  'No' 'No' 'Si' 'No' 'Si' 'No' 'Si' 'Si' 'Si' 'Si' 'No' 'Si' 'Si' 'No'
#  'Si' 'Si' 'Si' 'Si' 'No' 'No' 'Si' 'Si' 'Si' 'Si' 'Si' 'No' 'Si' 'Si'
#  'No' 'No' 'No' 'No' 'No' 'Si' 'Si' 'Si' 'Si' 'No' 'Si' 'No' 'Si' 'No'
#  'Si' 'Si' 'No' 'Si' 'Si' 'Si' 'Si' 'Si' 'Si' 'No' 'Si' 'No' 'Si' 'No'
#  'Si' 'Si' 'Si' 'Si' 'Si' 'Si' 'No' 'Si' 'Si' 'Si' 'Si' 'No' 'Si' 'No'
#  'No' 'Si' 'Si' 'Si' 'Si' 'Si' 'Si' 'No' 'No' 'No' 'Si' 'No' 'Si' 'Si'
#  'Si' 'Si' 'No' 'Si' 'Si' 'Si' 'No' 'Si' 'Si' 'No' 'Si' 'Si' 'No' 'No'
#  'No' 'No' 'Si' 'Si' 'No' 'Si' 'Si' 'No' 'No' 'No' 'Si' 'Si' 'Si' 'Si'
#  'No' 'Si' 'Si' 'Si' 'No' 'No' 'Si' 'No' 'No' 'Si' 'Si' 'Si' 'Si' 'No'
#  'Si' 'Si' 'No' 'Si' 'Si' 'No' 'No' 'No' 'Si' 'Si' 'Si' 'No' 'Si' 'Si'
#  'Si' 'No' 'Si' 'No' 'No' 'Si' 'Si' 'Si' 'Si' 'Si' 'No' 'No' 'Si' 'No'
#  'No' 'Si' 'Si' 'No' 'Si' 'Si' 'Si' 'Si' 'No' 'No' 'No' 'Si' 'Si' 'No'
#  'No' 'No' 'Si' 'Si' 'Si' 'No' 'No' 'Si' 'Si' 'Si' 'Si' 'Si' 'No' 'Si'
#  'Si' 'No' 'No' 'Si' 'Si' 'Si' 'Si' 'No' 'No' 'No' 'Si' 'Si' 'No' 'Si'
#  'No' 'No' 'Si' 'No' 'No' 'No' 'No' 'Si' 'No' 'Si' 'Si' 'Si' 'No' 'Si'
#  'Si' 'Si' 'Si' 'Si' 'Si' 'Si' 'No' 'Si' 'Si' 'Si' 'Si' 'Si' 'No' 'Si'
#  'Si' 'No' 'Si' 'Si' 'No' 'No' 'Si' 'No' 'No' 'No' 'Si' 'Si' 'Si' 'Si'
#  'Si' 'Si' 'Si' 'No' 'Si' 'Si' 'Si' 'Si' 'Si' 'No' 'No' 'Si' 'No' 'Si'
#  'Si' 'No' 'Si' 'No' 'Si' 'No' 'Si' 'Si' 'Si' 'Si' 'Si' 'Si' 'Si' 'Si'
#  'Si' 'Si' 'Si' 'Si' 'No' 'Si' 'Si' 'No' 'No' 'Si' 'Si' 'Si' 'Si' 'No'
#  'No' 'Si' 'Si' 'Si' 'No' 'Si' 'Si' 'No' 'Si' 'Si' 'Si' 'Si' 'Si' 'Si'
#  'No' 'No' 'No' 'Si' 'No' 'No' 'Si' 'No' 'Si' 'Si' 'No' 'Si' 'Si' 'No'
#  'Si' 'No' 'Si' 'Si' 'No' 'No' 'No' 'Si' 'Si' 'No' 'Si' 'No' 'Si' 'Si'
#  'Si' 'No' 'Si' 'Si' 'No' 'Si' 'Si' 'No' 'Si' 'No' 'No' 'Si' 'Si' 'Si'
#  'Si' 'Si' 'Si' 'Si' 'No' 'Si' 'No' 'Si' 'Si' 'Si' 'No' 'Si' 'No' 'Si'
#  'Si' 'No' 'Si' 'Si' 'Si' 'No' 'Si' 'Si' 'No' 'No' 'Si' 'Si' 'No' 'Si'
#  'Si' 'Si' 'Si' 'No' 'Si' 'No' 'No' 'Si' 'No' 'Si' 'Si' 'No' 'Si' 'Si'
#  'Si' 'Si' 'Si' 'Si' 'No' 'Si' 'Si' 'Si' 'Si' 'No' 'Si' 'No' 'Si' 'Si'
#  'Si' 'Si' 'Si' 'No' 'No' 'No' 'Si' 'Si' 'No' 'Si' 'Si' 'Si' 'Si' 'Si'
#  'No' 'Si' 'Si' 'Si' 'Si' 'Si' 'No' 'Si' 'Si' 'Si' 'Si' 'Si' 'Si' 'No'
#  'Si' 'Si' 'No' 'Si' 'Si' 'Si' 'Si' 'Si' 'Si' 'No' 'Si' 'Si' 'Si' 'No'
#  'No' 'Si' 'No' 'Si' 'Si' 'Si' 'Si' 'Si' 'Si' 'Si' 'Si' 'Si' 'No' 'No'
#  'Si' 'Si' 'No' 'No' 'No' 'No' 'No' 'Si' 'Si' 'No' 'Si' 'Si' 'Si' 'No'
#  'Si' 'Si' 'No' 'Si' 'Si' 'Si' 'Si' 'Si' 'Si' 'No' 'No' 'Si' 'No' 'No'
#  'Si' 'Si' 'No' 'Si' 'No' 'No' 'Si' 'No' 'Si' 'Si' 'No' 'Si' 'No' 'Si'
#  'Si' 'Si' 'Si' 'Si' 'Si' 'Si' 'No' 'No' 'Si' 'No' 'No' 'Si' 'Si' 'No'
#  'Si' 'Si' 'No' 'Si' 'Si' 'No' 'Si' 'Si' 'Si' 'No' 'No' 'Si' 'Si' 'No'
#  'No' 'Si' 'Si' 'No' 'Si' 'Si' 'Si' 'Si' 'No' 'Si' 'No' 'No' 'No' 'No'
#  'Si' 'Si' 'Si' 'No' 'Si' 'Si' 'Si' 'Si' 'Si' 'Si' 'Si' 'No' 'Si' 'No'
#  'Si' 'Si' 'Si' 'Si' 'No' 'No' 'Si' 'Si' 'No' 'Si' 'No' 'Si' 'Si' 'No'
#  'No' 'No' 'No' 'Si' 'No' 'Si' 'Si' 'No' 'No' 'Si' 'No' 'No' 'No' 'No'
#  'Si' 'No' 'Si' 'No' 'Si' 'Si' 'No' 'Si' 'Si' 'No' 'Si' 'Si' 'Si' 'Si'
#  'Si' 'No' 'No' 'No' 'No' 'No' 'Si' 'Si' 'Si' 'Si' 'No' 'Si' 'No' 'Si'
#  'No' 'Si' 'Si' 'Si' 'Si' 'No' 'No' 'Si' 'No' 'Si' 'No' 'Si' 'Si' 'Si'
#  'Si' 'No' 'Si' 'No' 'No' 'No' 'Si' 'No' 'Si' 'Si' 'Si' 'Si' 'No' 'Si'
#  'No' 'Si' 'Si' 'Si' 'No' 'No' 'Si' 'Si' 'Si' 'Si' 'Si' 'Si' 'Si' 'Si'
#  'No' 'No' 'Si' 'No' 'No' 'Si' 'Si' 'No' 'Si' 'No' 'Si' 'No' 'Si' 'Si'
#  'Si' 'No' 'Si' 'No' 'No' 'Si' 'Si' 'No' 'Si' 'No' 'Si' 'Si' 'Si' 'No'
#  'No' 'Si' 'No' 'No' 'Si' 'Si' 'Si' 'No' 'Si' 'No' 'No' 'Si' 'No' 'Si'
#  'Si' 'No' 'No' 'Si' 'Si' 'No' 'Si' 'No' 'No' 'No' 'No' 'Si' 'Si' 'No'
#  'Si' 'No' 'No' 'Si' 'Si' 'No' 'Si' 'Si' 'No' 'No' 'Si' 'No' 'Si' 'Si'
#  'No' 'No' 'No' 'No' 'No' 'No' 'Si' 'Si' 'Si' 'Si' 'No' 'No' 'No' 'Si'
#  'Si' 'Si' 'No' 'No' 'No' 'No' 'Si' 'Si' 'No' 'No' 'Si' 'Si' 'No' 'Si'
#  'No' 'No' 'No' 'Si' 'Si' 'Si' 'Si' 'No' 'No' 'No' 'No' 'Si' 'No' 'Si'
#  'Si' 'No' 'No' 'Si' 'Si' 'No' 'Si' 'No' 'No' 'No' 'Si' 'No' 'Si' 'No'
#  'Si' 'Si' 'Si' 'Si' 'Si' 'No' 'Si' 'Si' 'No' 'Si' 'No' 'Si' 'Si' 'Si'
#  'Si' 'Si' 'Si' 'No' 'No' 'No' 'Si' 'No' 'No' 'No' 'Si' 'Si' 'No' 'Si'
#  'Si' 'Si' 'Si' 'Si' 'Si' 'Si' 'Si' 'Si' 'Si' 'No' 'Si' 'No' 'Si' 'Si'
#  'No' 'No' 'Si' 'Si' 'No' 'Si']

# %% [markdown]
# ### Guardando los resultados de la predicción en un archivo csv

# %%
np.savetxt("results.csv", y_pred, delimiter=",", fmt='%s')

# %%
project.save_data(file_name="results.csv", data=pd.read_csv("results.csv", header=None).to_csv(header=["TARGET"], index=False))
# Out:
# {'file_name': 'results.csv',
#  'message': 'File saved to project storage.',
#  'bucket_name': 'btcanahuac-donotdelete-pr-u7zt94jlikswfz',
#  'asset_id': 'a60cb9e6-d757-47a1-b883-24ae2b34700e'}

# %% [markdown]
# <hr>
#
# ## ¡Felicitaciones!
#
# Si todo fue ejecutado sin errores, usted ya tiene un modelo basado en classificacion binaria y puede descargar sus resultados para subirlos como csv!
#
# Para enviar su solución, ve a la página:
#
# # https://anahuac.maratona.dev
